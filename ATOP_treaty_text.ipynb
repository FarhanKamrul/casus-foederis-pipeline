# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║  Cell 1 – Extract raw text from ATOP1005.pdf                       ║
# ╚════════════════════════════════════════════════════════════════════╝


# filename: extract_ATOP1005_text.ipynb  (inside the notebook itself)


# 1. Install the helper once (has no effect if already installed)
import sys, subprocess, json, pathlib, textwrap, importlib.util

def _ensure(package: str):
    if importlib.util.find_spec(package) is None:
        print(f"Installing {package} …")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])

_ensure("pdfplumber")

# 2. Set up paths  ── adapt RELATIVE_PDF if your notebook sits elsewhere
RELATIVE_PDF = r"atop_version_5.1_codesheets\ATOP Version 5.1 Codesheets\ATOP1005.pdf"

nb_dir   = pathlib.Path.cwd()          # folder that holds the .ipynb
pdf_path = nb_dir / pathlib.Path(RELATIVE_PDF)
txt_path = pdf_path.with_suffix(".txt")   # e.g.  ATOP1005.txt  in same folder as PDF

if not pdf_path.exists():
    raise FileNotFoundError(
        f"PDF not found at {pdf_path}\n"
        "→ Double-check the relative path from the notebook’s location."
    )

# 3. Extract every page’s text
import pdfplumber, re

with pdfplumber.open(pdf_path) as pdf:
    raw_text = "\n".join(
        page.extract_text() or ""   # keeps order; returns '' if page is image-only
        for page in pdf.pages
    )

# Optional: collapse multiple newlines for easier regex design
raw_text_clean = re.sub(r"\n{2,}", "\n\n", raw_text)

# 4. Save to a .txt file for manual inspection
txt_path.write_text(raw_text_clean, encoding="utf-8")
print(f"✓ Extracted {len(raw_text):,} characters from {pdf_path.name}")
print(f"  Dump saved to: {txt_path.relative_to(nb_dir)}")

# 5. Quick preview (first 40 lines) so you can see what you have
preview_lines = 300
print("\n" + "="*60 + f"\nPreview (first {preview_lines} lines):\n" + "="*60)
print("\n".join(raw_text_clean.splitlines()[:preview_lines]))
# Out:
# ✓ Extracted 14,057 characters from ATOP1005.pdf
#   Dump saved to: atop_version_5.1_codesheets\ATOP Version 5.1 Codesheets\ATOP1005.txt
#
# ============================================================
# Preview (first 300 lines):
# ============================================================
# ALLIANCE TREATY OBLIGATIONS AND PROVISIONS (ATOP)
# CODING SHEET
# Brett Ashley Leeds with Jeffrey M. Ritter, Sara McLaughlin Mitchell, and Andrew G. Long
# Department of Political Science, Rice University, P.O. Box 1892-MS 24, Houston, TX 77251-1892
# Version 8.0; August, 2000
# SECTION I: FORMATION, MEMBERS, AND DURATION
# 1. ATOP ID: # 1005.
# 2. COW Alliance # (if applicable): N/A.
# 3. Signature date(s) (may vary for members in multilateral alliances):
# January 3, 1815.
# See # 4 below for accession dates.
# 4. Members of alliance (use COW country codes):
# 200 United Kingdom
# 220 France
# 300 Austria
# 245 Bavaria (January 13, 1815)
# 240 Hanover (January 19, 1815)
# 210 Netherlands (January 31, 1815).
# 5. Was the alliance signed during war? If so, which war, and which member(s) was at war? (check COW data)
# No.
# 6. Means by which alliance was established (e.g., treaty, executive agreement, diplomatic notes, etc.): (Only select “treaty” if the
# agreement requires ratification.)
# Treaty.
# 7. Was the treaty public, public but with secret articles, or secret? If secret articles, describe the content of secret articles.
# Public with secret article. The secret article specifies that Bavaria and Hanover will be invited to join and that if they do not
# join they will not enjoy any of the advantages stipulated by the treaty.
# 8. Are there provisions for adding additional members mentioned in the treaty? (Yes, No) If Yes, describe these provisions.
# Yes. The parties reserve the right to invite all other powers to accede to this treaty on the terms and conditions they agree upon
# (Art.XII).
# 9. Are specific state(s) mentioned as possible future members of the alliance? (Yes, No) If Yes, which state(s)?
# Yes. The parties will invite Bavaria and Hanover to accede (Secret Article).
# 10. Are there specific provisions in the treaty concerning the length of time the treaty is to last? (Yes, No) If Yes, describe.
# No.
# 11. Are there conditions under which members may renounce the treaty? If Yes, describe these conditions.
# No.
# 12. Are there specific provisions in the treaty concerning renewal of the treaty? (Yes, No) If Yes, describe these provisions.
# No.
# 13. Number of times alliance renewed, dates of renewal, and means by which alliance was renewed (Do not include automatic
# renewals):
# Zero.
# 14. Termination date(s) (may vary for members in multilateral alliances) and source(s) for termination dates(s):
# February 8, 1815.
# 15. Describe what caused the alliance to terminate.
# Agreement on the territorial division in Saxony (Schroeder, 1994: 536).
# SECTION II: OBLIGATIONS
# 16. Type of alliance (defense pact, neutrality pact, nonaggression pact, consultation pact, offense pact): (List all that apply to any
# member of the alliance.)
# Defense Pact
# Consultation Pact.
# 17. Type of alliance as coded in COW data (if applicable): N/A.
# 18. Describe the obligations of the alliance partners.
# The parties commit themselves reciprocally, and every party with respect to the other, to act together with the most perfect
# disinterest and with the most complete good faith, to carry out the arrangements of the Treaty of Paris in a way that is as much
# as possible in accordance with the true spirit of the treaty. If because of, or in hatred of, the propositions that they have made
# by common accord, the possessions of one of the parties are attacked, the other parties are obliged to consider themselves as
# attacked and to act together and to assist each other to repel all such aggression with the forces hereafter specified (Art.I).
# The parties will resolve all other matters [other than mentioned in Art.X] by common accord, adhering as much as the
# circumstances permit to the Treaty of Paris (Art.XI).
# The UK has no possession of the European continent that might be attacked in a case of war and the parties agree that if the
# British territories of Hanover and the territories of the Prince of the UK, which are under the administration of the UK, shall be
# attacked, the other parties are obliged to repel this aggression as if it was directed against their territories (Art.XIII).
# 19. Are any of the obligations contingent upon any of the following: specific adversary, specific location, specific ongoing conflict,
# number of adversaries, noncompliance with a specific demand, attack, nonprovocation of enemy, or prior agreement among partners?
# (List all that apply)
# No.
# 20. Describe the nature of the limits to obligations listed in #19.
# N/A.
# 21. Are there any additional provisions for assistance in the event of war? (e.g., promise not to participate in economic sanctions against
# partner, promise not to aid internal or external enemies, etc.) (Yes, No) If Yes, describe.
# Yes. If (…) one of the parties finds itself threatened by one or more powers, the other two parties must, through a friendly
# intervention, make an effort to prevent the aggression (Art.II).
# If the UK has difficulty to provide within the fixed term the troops stipulated by the treaty and to maintain them ready to fight,
# because of the location of the war, it reserves itself the right to furnish its contingent to the attacked ally in foreign troops at its
# expense or to pay annually to the attacked party a sum of money, calculated at 20 livres sterling for each soldier of the infantry
# and 30 livres sterling for each soldier of the cavalry. The mode in which the UK will furnish its aid will be amicably
# determines for each particular case between the UK and the threatened or attacked power as soon as the requisition occurs
# (Art.V).
# 22. Are there any additional limits to the alliance obligations or conditions under which treaty obligations do not apply that were not
# listed in #19? (Yes, No) If Yes, describe.
# No.
# 23. Is a specific target/threat mentioned as the object of the treaty? (Yes, No) (Answering Yes to this question does not necessarily mean
# that obligations are limited only to this adversary.) If Yes, list the target nation(s) (using COW country codes if possible) and describe
# the general nature of the reference to the target of the treaty.
# No.
# 24. Are the treaty obligations symmetric? (That is, do all members commit to the same obligations?) (Yes, No) If No, describe.
# Yes.
# 25. Does the treaty prohibit members from settling conflicts independently (no separate peace)? (Yes, No) If Yes, describe.
# Yes. The parties promise each other that if they help each other in the way specified below and they find themselves involved
# in a direct war against the power against which they have provided help to their ally, neither of the allies will conclude peace
# without the consent of the other (Art.VIII).
# 26. Does the treaty have provisions requiring that the contracting parties consult before making commitments to third parties (excluding
# no separate peace provisions discussed above)? (Yes, No) If Yes, describe these provisions.
# No.
# 27. Does the treaty specify that the contracting parties must not enter into any other alliances that are directed against the alliance in
# question? (Yes, No) If Yes, describe.
# Yes – Article IX – The present treaty does not prohibit the members from forming other alliances, as long as they are not
# contrary to the goal of this alliance.
# 28. Additional coder comments regarding treaty obligations:
# SECTION III: INSTITUTIONALIZATION OF THE ALLIANCE
# 29. Does the treaty make reference to the potential for conflict among members of the alliance? (Yes, No) If Yes, describe.
# No.
# 30. Does the treaty discuss mediation/arbitration or other means of settling disputes among the signatories? (Yes, No) If Yes, describe.
# No.
# 31. Does the treaty require official contact among the military forces of the participating states? (Yes, No) If Yes, describe. (Note
# whether official contact is required only in the event of hostilities or also during peacetime.)
# Yes. The parties commit themselves, should a war occur, to agree amicably on a system of cooperation that is the most
# appropriate given the nature and the objective of the war, and to organize in this way the war plans that concern the command
# to which all facilities are given, the lines of operation of the corps that will be used, the marches of the corps, and their supplies
# in provisions and fodder (Art.VI). In case that the stipulated aid is not proportional to the circumstances, the parties reserve will
# agree among themselves, with as little delay as possible, what additional aid is necessary and shall be provided (Art.VII).
# 32. Does the treaty include provisions for military aid? (e.g., grants, loans, transfer of technology, training) (Yes, No) If Yes, describe
# these provisions.
# No.
# 33. Does the treaty provide for integrated command of military forces while the alliance is in effect (peacetime as well as wartime)?
# (Yes, No) If Yes, describe.
# No.
# 34. Does the treaty require subordination of the forces of one or more member states to another in the event of hostilities? (Yes, No) If
# Yes, describe.
# No.
# 35. Does the treaty establish any organizations? (include provisions for regularly scheduled meetings) (Yes, No) If Yes, describe.
# No.
# 36. Does the treaty provide for joint military bases, or for one or more states to place troops in the territory of one or more other states?
# (Yes, No) If Yes, describe.
# No.
# 37. Does the treaty specify contribution levels (funds, troops, etc.)? (Yes, No) If Yes, describe.
# Yes. In case that their efforts to prevent aggression are unsuccessful, they promise to come to the aid of the attacked party with
# 150,000 troops (Art.III). These auxiliary troops shall be composed of 120,000 soldiers of the infantry and 30,000 soldiers of the
# cavalry with munitions that is propostional to the number of troops (Art.IV).
# If the UK has difficulty to provide within the fixed term the troops stipulated by the treaty and to maintain them ready to fight,
# because of the location of the war, it reserves itself the right to furnish its contingent to the attacked ally in foreign troops at its
# expense or to pay annually to the attacked party a sum of money, calculated at 20 livres sterling for each soldier of the infantry
# and 30 livres sterling for each soldier of the cavalry. The mode in which the UK will furnish its aid will be amicably
# determines for each particular case between the UK and the threatened or attacked power as soon as the requisition occurs
# (Art.V).
# 38. Does the treaty contain any provisions regarding coordinated increase of armaments, reduction of armaments, prohibition of
# weapons, or rules of warfare? (Yes, No) If Yes, describe such provisions.
# No.
# 39. Does the treaty explicitly permit or prohibit the acquisition of territory not currently held by either ally? (Yes, No) If Yes, describe
# reference.
# Yes. The parties, having no interest in increasing their properties and only motivated by the desire to protect each other’s rights
# and duties as independent states, commit themselves, in case a war shall occur, to consider the Treaty of Paris to regulate the
# peace and the boundaries of their respective territories (Art.X).
# 40. Does the treaty include discussion of the division of gains from any future conflict? (Yes, No) If Yes, describe.
# No.
# 41. Does the treaty include discussion of demobilization/withdrawal following conflict? (Yes, No) If Yes, describe.
# No.
# 42. Are there any other provisions in the treaty that describe the means through which the states will coordinate their military efforts and
# policies? (Yes, No) If Yes, describe.
# No.
# 43. Additional coder comments regarding references to alliance institutionalization:
# SECTION IV: TREATY CONTEXT
# 44. Does the treaty state that it nullifies any existing treaties signed by one or more of the contracting parties? (Yes, No) If Yes, list the
# treaties/agreements that are nullified and describe the treaty reference.
# No.
# 45. Does the treaty state that it modifies any existing treaties signed by one or more of the contracting parties? (Yes, No) If Yes, list the
# treaties/agreements that are modified and describe the treaty reference.
# No.
# 46. Does the treaty state that it includes any existing treaties signed by one or more of the contracting parties? (Yes, No) If Yes, list the
# treaties/agreements that are included and describe the treaty reference.
# Yes. The treaty reinforces the provisions of the Treaty of Paris (Preamble, Art.I, Art.X and XI).
# 47. Does the treaty make any references to international organizations? (Yes, No) If Yes, list the international organization and describe
# the nature of the reference.
# No.
# 48. Does the treaty make any references to other existing alliances? (Yes, No) If Yes, list the alliance and describe the nature of the
# reference.
# No.
# 49. Are there any companion agreements referenced in the treaty? (Yes, No) If Yes, describe the agreements.
# No.
# 50. Does the treaty include statements regarding non-military cooperation (e.g., economic, cultural, scientific exchange)? (Yes, No) If
# Yes, describe.
# No.
# 51. Does the treaty resolve other conflicts among the parties to the alliance? (Yes, No) If Yes, describe.
# No.
# 52. Does the treaty propose/enforce settlement of a conflict not involving parties to the alliance? (Yes, No) If Yes, describe.
# No.
# 53. Does the treaty propose other agreements among the contracting parties? (Yes, No) If Yes, describe.
# No.
# 54. Does the treaty mention unresolved conflicts among the contracting parties? (Yes, No) If Yes, describe.
# No.
# 55. Does the treaty include provisions for economic aid or other enticements (include trade concessions, post war recovery, etc.)? (Yes,
# No) If Yes, describe these provisions.
# No.
# 56. Does the treaty describe circumstances under which one party may intervene in the internal politics of another party or specifically
# commit the states to non-intervention? (Yes, No) If Yes, describe.
# No.
# SECTION V: DOCUMENTATION
# 57. Additional coder comments on this alliance treaty: Coded from French.
# 58. Source of coding information (e.g., treaty, treaty and secondary sources, secondary sources only, etc.): Treaty.
# 59. Treaty citation: BFSP, vol.2, p.1001.
# 60. Date of last revision of this coding sheet: 02/10/05.
# 61. Coder: Jeff Ritter, Michaela Mattes, Ashley Leeds.

# %%
import re
import pandas as pd
from pathlib import Path
import sys
import subprocess
import importlib.util

GLOBAL_SINGLE_PDF = "atop_version_5.1_codesheets\ATOP Version 5.1 Codesheets\ATOP1415.1.pdf"

# Ensure required packages are installed
def ensure_package(package: str):
    """Install package if not already installed"""
    if importlib.util.find_spec(package) is None:
        print(f"Installing {package}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# Install required packages
ensure_package("pdfplumber")
ensure_package("pandas")
ensure_package("python-dateutil")       # ← add just below the others
from dateutil.parser import parse as _dt_parse



import pdfplumber

# Define all questions with exact text for faster matching
QUESTIONS = {
    "Q1": {
        "short": "ATOP_ID",
        "full": "ATOP ID",
        "question_text": "1. ATOP ID: "
    },
    "Q2": {
        "short": "COW_Alliance_Number",
        "full": "COW Alliance # (if applicable)",
        "question_text": "2. COW Alliance # (if applicable):"
    },
    "Q3": {
        "short": "Signature_Date",
        "full": "Signature date(s) (may vary for members in multilateral alliances)",
        "question_text": "3. Signature date(s) (may vary for members in multilateral alliances):"
    },
    "Q4": {
        "short": "Members",
        "full": "Members of alliance (use COW country codes)",
        "question_text": "4. Members of alliance (use COW country codes):"
    },
    "Q5": {
        "short": "Signed_During_War",
        "full": "Was the alliance signed during war? If so, which war, and which member(s) was at war?",
        "question_text": "5. Was the alliance signed during war? If so, which war, and which member(s) was at war? (check COW data)"
    },
    "Q6": {
    "short": "Establishment_Means",
    "full": (
        "Means by which alliance was established (e.g., treaty, executive agreement, "
        "diplomatic notes, etc.): (Only select \"treaty\" if the\nagreement requires "
        "ratification.)"
    ),
    # NOTE the explicit  \n  before the word “agreement” and the curly quotes
    "question_text": (
        "6. Means by which alliance was established (e.g., treaty, executive agreement, "
        "diplomatic notes, etc.): (Only select “treaty” if the\nagreement requires "
        "ratification.)"
    )
    },
    "Q7": {
        "short": "Public_Secret_Status",
        "full": "Was the treaty public, public but with secret articles, or secret?",
        "question_text": "7. Was the treaty public, public but with secret articles, or secret? If secret articles, describe the content of secret articles."
    },
    "Q8": {
        "short": "Additional_Members_Provisions",
        "full": "Are there provisions for adding additional members mentioned in the treaty?",
        "question_text": "8. Are there provisions for adding additional members mentioned in the treaty? (Yes, No) If Yes, describe these provisions."
    },
    "Q9": {
        "short": "Specific_Future_Members",
        "full": "Are specific state(s) mentioned as possible future members of the alliance?",
        "question_text": "9. Are specific state(s) mentioned as possible future members of the alliance? (Yes, No) If Yes, which state(s)?"
    },
    "Q10": {
        "short": "Treaty_Duration",
        "full": "Are there specific provisions in the treaty concerning the length of time the treaty is to last?",
        "question_text": "10. Are there specific provisions in the treaty concerning the length of time the treaty is to last? (Yes, No) If Yes, describe."
    },
    "Q11": {
        "short": "Renounce_Conditions",
        "full": "Are there conditions under which members may renounce the treaty?",
        "question_text": "11. Are there conditions under which members may renounce the treaty? If Yes, describe these conditions."
    },
    "Q12": {
        "short": "Renewal_Provisions",
        "full": "Are there specific provisions in the treaty concerning renewal of the treaty?",
        "question_text": "12. Are there specific provisions in the treaty concerning renewal of the treaty? (Yes, No) If Yes, describe these provisions."
    },
    "Q13": {
        "short": "Times_Renewed",
        "full": "Number of times alliance renewed, dates of renewal, and means by which alliance was renewed",
        "question_text": "13. Number of times alliance renewed, dates of renewal, and means by which alliance was renewed (Do not include automatic\nrenewals):"
    },
    "Q14": {
        "short": "Termination_Date",
        "full": "Termination date(s) and source(s) for termination dates(s)",
        "question_text": "14. Termination date(s) (may vary for members in multilateral alliances) and source(s) for termination dates(s):"
    },
    "Q15": {
        "short": "Termination_Cause",
        "full": "Describe what caused the alliance to terminate",
        "question_text": "15. Describe what caused the alliance to terminate."
    },
    "Q16": {
        "short": "Alliance_Type",
        "full": "Type of alliance (defense pact, neutrality pact, nonaggression pact, consultation pact, offense pact)",
        "question_text": "16. Type of alliance (defense pact, neutrality pact, nonaggression pact, consultation pact, offense pact): (List all that apply to any\nmember of the alliance.)"
    },
    "Q17": {
        "short": "COW_Alliance_Type",
        "full": "Type of alliance as coded in COW data (if applicable)",
        "question_text": "17. Type of alliance as coded in COW data (if applicable):"
    },
    "Q18": {
        "short": "Obligations",
        "full": "Describe the obligations of the alliance partners",
        "question_text": "18. Describe the obligations of the alliance partners."
    },
    "Q19": {
        "short": "Contingencies",
        "full": "Are any of the obligations contingent upon any of the following",
        "question_text": "19. Are any of the obligations contingent upon any of the following: specific adversary, specific location, specific ongoing conflict,\nnumber of adversaries, noncompliance with a specific demand, attack, nonprovocation of enemy, or prior agreement among partners?\n(List all that apply)"
    },
    "Q20": {
        "short": "Limits_Description",
        "full": "Describe the nature of the limits to obligations listed in #19",
        "question_text": "20. Describe the nature of the limits to obligations listed in #19."
    },
    "Q21": {
        "short": "Additional_War_Provisions",
        "full": "Are there any additional provisions for assistance in the event of war?",
        "question_text": "21. Are there any additional provisions for assistance in the event of war? (e.g., promise not to participate in economic sanctions against\npartner, promise not to aid internal or external enemies, etc.) (Yes, No) If Yes, describe."
    },
    "Q22": {
        "short": "Additional_Limits",
        "full": "Are there any additional limits to the alliance obligations or conditions",
        "question_text": "22. Are there any additional limits to the alliance obligations or conditions under which treaty obligations do not apply that were not\nlisted in #19? (Yes, No) If Yes, describe."
    },
    "Q23": {
        "short": "Target_Threat",
        "full": "Is a specific target/threat mentioned as the object of the treaty?",
        "question_text": "23. Is a specific target/threat mentioned as the object of the treaty? (Yes, No) (Answering Yes to this question does not necessarily mean\nthat obligations are limited only to this adversary.) If Yes, list the target nation(s) (using COW country codes if possible) and describe\nthe general nature of the reference to the target of the treaty."
    },
    "Q24": {
        "short": "Symmetric_Obligations",
        "full": "Are the treaty obligations symmetric?",
        "question_text": "24. Are the treaty obligations symmetric? (That is, do all members commit to the same obligations?) (Yes, No) If No, describe."
    },
    "Q25": {
        "short": "No_Separate_Peace",
        "full": "Does the treaty prohibit members from settling conflicts independently (no separate peace)?",
        "question_text": "25. Does the treaty prohibit members from settling conflicts independently (no separate peace)? (Yes, No) If Yes, describe."
    },
    "Q26": {
        "short": "Consult_Third_Parties",
        "full": "Does the treaty have provisions requiring that the contracting parties consult before making commitments to third parties",
        "question_text": "26. Does the treaty have provisions requiring that the contracting parties consult before making commitments to third parties (excluding\nno separate peace provisions discussed above)? (Yes, No) If Yes, describe these provisions."
    },
    "Q27": {
        "short": "No_Contrary_Alliances",
        "full": "Does the treaty specify that the contracting parties must not enter into any other alliances that are directed against the alliance",
        "question_text": "27. Does the treaty specify that the contracting parties must not enter into any other alliances that are directed against the alliance in\nquestion? (Yes, No) If Yes, describe."
    },
    "Q28": {
        "short": "Additional_Obligations_Comments",
        "full": "Additional coder comments regarding treaty obligations",
        "question_text": "28. Additional coder comments regarding treaty obligations:"
    },
    "Q29": {
        "short": "Internal_Conflict_Reference",
        "full": "Does the treaty make reference to the potential for conflict among members of the alliance?",
        "question_text": "29. Does the treaty make reference to the potential for conflict among members of the alliance? (Yes, No) If Yes, describe."
    },
    "Q30": {
        "short": "Dispute_Settlement",
        "full": "Does the treaty discuss mediation/arbitration or other means of settling disputes among the signatories?",
        "question_text": "30. Does the treaty discuss mediation/arbitration or other means of settling disputes among the signatories? (Yes, No) If Yes, describe."
    },
    "Q31": {
        "short": "Military_Contact",
        "full": "Does the treaty require official contact among the military forces of the participating states?",
        "question_text": "31. Does the treaty require official contact among the military forces of the participating states? (Yes, No) If Yes, describe. (Note\nwhether official contact is required only in the event of hostilities or also during peacetime.)"
    },
    "Q32": {
        "short": "Military_Aid",
        "full": "Does the treaty include provisions for military aid?",
        "question_text": "32. Does the treaty include provisions for military aid? (e.g., grants, loans, transfer of technology, training) (Yes, No) If Yes, describe\nthese provisions."
    },
    "Q33": {
        "short": "Integrated_Command",
        "full": "Does the treaty provide for integrated command of military forces while the alliance is in effect?",
        "question_text": "33. Does the treaty provide for integrated command of military forces while the alliance is in effect (peacetime as well as wartime)?\n(Yes, No) If Yes, describe."
    },
    "Q34": {
        "short": "Force_Subordination",
        "full": "Does the treaty require subordination of the forces of one or more member states to another in the event of hostilities?",
        "question_text": "34. Does the treaty require subordination of the forces of one or more member states to another in the event of hostilities? (Yes, No) If\nYes, describe."
    },
    "Q35": {
        "short": "Organizations_Established",
        "full": "Does the treaty establish any organizations?",
        "question_text": "35. Does the treaty establish any organizations? (include provisions for regularly scheduled meetings) (Yes, No) If Yes, describe."
    },
    "Q36": {
        "short": "Joint_Bases_Troops",
        "full": "Does the treaty provide for joint military bases, or for one or more states to place troops in the territory of one or more other states?",
        "question_text": "36. Does the treaty provide for joint military bases, or for one or more states to place troops in the territory of one or more other states?\n(Yes, No) If Yes, describe."
    },
    "Q37": {
        "short": "Contribution_Levels",
        "full": "Does the treaty specify contribution levels (funds, troops, etc.)?",
        "question_text": "37. Does the treaty specify contribution levels (funds, troops, etc.)? (Yes, No) If Yes, describe."
    },
    "Q38": {
        "short": "Armament_Provisions",
        "full": "Does the treaty contain any provisions regarding coordinated increase of armaments, reduction of armaments, prohibition of weapons, or rules of warfare?",
        "question_text": "38. Does the treaty contain any provisions regarding coordinated increase of armaments, reduction of armaments, prohibition of\nweapons, or rules of warfare? (Yes, No) If Yes, describe such provisions."
    },
    "Q39": {
        "short": "Territory_Acquisition",
        "full": "Does the treaty explicitly permit or prohibit the acquisition of territory not currently held by either ally?",
        "question_text": "39. Does the treaty explicitly permit or prohibit the acquisition of territory not currently held by either ally? (Yes, No) If Yes, describe\nreference."
    },
    "Q40": {
        "short": "Division_of_Gains",
        "full": "Does the treaty include discussion of the division of gains from any future conflict?",
        "question_text": "40. Does the treaty include discussion of the division of gains from any future conflict? (Yes, No) If Yes, describe."
    },
    "Q41": {
        "short": "Demobilization_Withdrawal",
        "full": "Does the treaty include discussion of demobilization/withdrawal following conflict?",
        "question_text": "41. Does the treaty include discussion of demobilization/withdrawal following conflict? (Yes, No) If Yes, describe."
    },
    "Q42": {
        "short": "Other_Coordination",
        "full": "Are there any other provisions in the treaty that describe the means through which the states will coordinate their military efforts and policies?",
        "question_text": "42. Are there any other provisions in the treaty that describe the means through which the states will coordinate their military efforts and\npolicies? (Yes, No) If Yes, describe."
    },
    "Q43": {
        "short": "Additional_Institutionalization_Comments",
        "full": "Additional coder comments regarding references to alliance institutionalization",
        "question_text": "43. Additional coder comments regarding references to alliance institutionalization:"
    },
    "Q44": {
        "short": "Nullifies_Treaties",
        "full": "Does the treaty state that it nullifies any existing treaties signed by one or more of the contracting parties?",
        "question_text": "44. Does the treaty state that it nullifies any existing treaties signed by one or more of the contracting parties? (Yes, No) If Yes, list the\ntreaties/agreements that are nullified and describe the treaty reference."
    },
    "Q45": {
        "short": "Modifies_Treaties",
        "full": "Does the treaty state that it modifies any existing treaties signed by one or more of the contracting parties?",
        "question_text": "45. Does the treaty state that it modifies any existing treaties signed by one or more of the contracting parties? (Yes, No) If Yes, list the\ntreaties/agreements that are modified and describe the treaty reference."
    },
    "Q46": {
        "short": "Includes_Treaties",
        "full": "Does the treaty state that it includes any existing treaties signed by one or more of the contracting parties?",
        "question_text": "46. Does the treaty state that it includes any existing treaties signed by one or more of the contracting parties? (Yes, No) If Yes, list the\ntreaties/agreements that are included and describe the treaty reference."
    },
    "Q47": {
        "short": "International_Organizations",
        "full": "Does the treaty make any references to international organizations?",
        "question_text": "47. Does the treaty make any references to international organizations? (Yes, No) If Yes, list the international organization and describe\nthe nature of the reference."
    },
    "Q48": {
        "short": "Other_Alliances",
        "full": "Does the treaty make any references to other existing alliances?",
        "question_text": "48. Does the treaty make any references to other existing alliances? (Yes, No) If Yes, list the alliance and describe the nature of the\nreference."
    },
    "Q49": {
        "short": "Companion_Agreements",
        "full": "Are there any companion agreements referenced in the treaty?",
        "question_text": "49. Are there any companion agreements referenced in the treaty? (Yes, No) If Yes, describe the agreements."
    },
    "Q50": {
        "short": "Non_Military_Cooperation",
        "full": "Does the treaty include statements regarding non-military cooperation?",
        "question_text": "50. Does the treaty include statements regarding non-military cooperation (e.g., economic, cultural, scientific exchange)? (Yes, No) If\nYes, describe."
    },
    "Q51": {
        "short": "Resolves_Conflicts",
        "full": "Does the treaty resolve other conflicts among the parties to the alliance?",
        "question_text": "51. Does the treaty resolve other conflicts among the parties to the alliance? (Yes, No) If Yes, describe."
    },
    "Q52": {
        "short": "Enforces_External_Settlement",
        "full": "Does the treaty propose/enforce settlement of a conflict not involving parties to the alliance?",
        "question_text": "52. Does the treaty propose/enforce settlement of a conflict not involving parties to the alliance? (Yes, No) If Yes, describe."
    },
    "Q53": {
        "short": "Proposes_Agreements",
        "full": "Does the treaty propose other agreements among the contracting parties?",
        "question_text": "53. Does the treaty propose other agreements among the contracting parties? (Yes, No) If Yes, describe."
    },
    "Q54": {
        "short": "Unresolved_Conflicts",
        "full": "Does the treaty mention unresolved conflicts among the contracting parties?",
        "question_text": "54. Does the treaty mention unresolved conflicts among the contracting parties? (Yes, No) If Yes, describe."
    },
    "Q55": {
        "short": "Economic_Aid",
        "full": "Does the treaty include provisions for economic aid or other enticements?",
        "question_text": "55. Does the treaty include provisions for economic aid or other enticements (include trade concessions, post war recovery, etc.)? (Yes,\nNo) If Yes, describe these provisions."
    },
    "Q56": {
        "short": "Internal_Politics_Intervention",
        "full": "Does the treaty describe circumstances under which one party may intervene in the internal politics of another party?",
        "question_text": "56. Does the treaty describe circumstances under which one party may intervene in the internal politics of another party or specifically\ncommit the states to non-intervention? (Yes, No) If Yes, describe."
    },
    "Q57": {
        "short": "Additional_Comments",
        "full": "Additional coder comments on this alliance treaty",
        "question_text": "57. Additional coder comments on this alliance treaty:"
    },
    "Q58": {
        "short": "Source_of_Coding",
        "full": "Source of coding information",
        "question_text": "58. Source of coding information (e.g., treaty, treaty and secondary sources, secondary sources only, etc.):"
    },
    "Q59": {
        "short": "Treaty_Citation",
        "full": "Treaty citation",
        "question_text": "59. Treaty citation:"
    },
    "Q60": {
        "short": "Last_Revision_Date",
        "full": "Date of last revision of this coding sheet",
        "question_text": "60. Date of last revision of this coding sheet:"
    },
    "Q61": {
        "short": "Coder",
        "full": "Coder",
        "question_text": "61. Coder:"
    }
}

def parse_single_date(text):
    """
    Return ISO date ('YYYY-MM-DD') if `text` looks like a date.
    Otherwise return None.
    """
    try:
        clean = text.strip().rstrip('.')        # drop trailing period
        dt = _dt_parse(clean, fuzzy=True)       # handles 'March 9, 1833'
        return dt.date().isoformat()
    except (ValueError, OverflowError):
        return None

def extract_countries(text):
    """
    Return a semicolon-separated string of CountryName(code) pairs found in `text`.
    Handles both '365 Russia 200 United Kingdom.' and 'Russia (365)' layouts, collecting ALL occurrences.
    """
    pairs = []

    # Pattern A – code first, then name (e.g. "365 Russia 200 United Kingdom.")
    for code, name in re.findall(
        r'\b(\d{3})\s+([A-Z][A-Za-z.\- ]+?)'               # capture 3-digit code + country name
        r'(?='                                             # but stop when you see:
          r'(?:\s+\d{3}\s)'      #   – another code (e.g. " 200 ")
          r'|[.,;\n]'            #   – or punctuation: . , ; or newline
          r'|$'                  #   – or end-of-string
        r')',
        text
    ):
        pair = f"{name.strip()}({code})"
        if pair not in pairs:
            pairs.append(pair)

    # Pattern B – name first, then code in parentheses (e.g. "Russia (365)")
    for name, code in re.findall(
        r'\b([A-Z][A-Za-z.\- ]+?)\s*\(\s*(\d{3})\s*\)',
        text
    ):
        pair = f"{name.strip()}({code})"
        if pair not in pairs:
            pairs.append(pair)

    return ";".join(pairs)





def extract_text_from_pdf(pdf_path):
    """Extract text from PDF file using pdfplumber"""
    print(f"Extracting text from {pdf_path}")
    
    try:
        with pdfplumber.open(pdf_path) as pdf:
            # Extract text from all pages
            raw_text = "\n".join(
                page.extract_text() or ""  # returns '' if page is image-only
                for page in pdf.pages
            )
        
        # Clean up multiple newlines
        raw_text_clean = re.sub(r"\n{2,}", "\n\n", raw_text)
        
        print(f"✓ Extracted {len(raw_text):,} characters from {Path(pdf_path).name}")
        return raw_text_clean
    
    except Exception as e:
        print(f"Error extracting text from {pdf_path}: {str(e)}")
        return None

def categorize_answer(answer_text):
    """Categorize the answer based on its content"""
    answer_clean = answer_text.strip()
    
    # Check for Yes/No answers
    if answer_clean.lower() in ['yes', 'no', 'yes.', 'no.', 'n/a', 'n/a.', 'zero', 'zero.']:
        return "Yes/No+Text"
    
    # Check for coded list answers (contains semicolons or specific patterns)
    if ';' in answer_clean and len(answer_clean) < 100:
        return "Coded_List"
    
    # Check for multiple items (contains "and" or comma-separated short items)
    if (',' in answer_clean or ' and ' in answer_clean.lower()) and len(answer_clean) < 100:
        return "Multiple"
    
    
    # Check for numeric answers
    if re.match(r'^\d+\.?$', answer_clean):
        return "Numeric"
    
    # Default to text for longer answers
    return "Text"

import re

def fast_extract_answers(text, alliance_id=None, alliance_name=None):
    """
    Fast extraction using whitespace-flattened search so that slight
    differences in line breaks or punctuation don’t break question matching.
    Returns a list of row dicts with keys:
      Alliance_ID, Alliance_Name, Question_ID, Question_Short, Question_Full,
      Answer_YesNo, Answer_Text, Answer_Category, Decoded_Countries, Text_Length
    """
    # —————————————— Alliance ID / Name logic (unchanged) ——————————————
    if alliance_id is None:
        id_pos = text.find("1. ATOP ID:")
        if id_pos != -1:
            start = id_pos + len("1. ATOP ID:")
            end   = text.find("\n", start)
            alliance_id = text[start:end].strip().replace("#", "").strip()
        else:
            alliance_id = "Unknown"
    if alliance_name is None:
        alliance_name = f"Alliance_{alliance_id}"

    # —————————————— Flatten for robust searching ——————————————
    text_search = re.sub(r"\s+", " ", text).strip()

    # —————————————— Locate every question position ——————————————
    question_positions = []
    for q_id, q_info in QUESTIONS.items():
        q_flat = re.sub(r"\s+", " ", q_info["question_text"]).strip()
        matches = [m.start() for m in re.finditer(re.escape(q_flat), text_search)]
        if matches:
            pos = matches[-1]
            question_positions.append((q_id, pos, len(q_flat), q_info))
    question_positions.sort(key=lambda x: x[1])

    rows = []
    # —————————————— Extract each answer block ——————————————
    for i, (q_id, pos, plen, q_info) in enumerate(question_positions):
        answer_start = pos + plen
        if i + 1 < len(question_positions):
            answer_end = question_positions[i + 1][1]
        else:
            # last question → up to common markers or end
            answer_end = len(text_search)
            for marker in ["SECTION", "Source:", "Date of last revision:"]:
                mpos = text_search.find(marker, answer_start)
                if 0 <= mpos < answer_end:
                    answer_end = mpos

        # slice & basic cleanup
        answer_text = text_search[answer_start:answer_end].strip()
        answer_text = re.sub(r'^#\s*', '', answer_text)  # drop leading "# "
        answer_text = re.sub(
            r'^See\s+#?\s*\d+\s+below[^\n]*\n?',
            '',
            answer_text,
            flags=re.I
        )
        answer_text = re.sub(
            r'^SECTION\s+[IVXLCDM]+\s*:[^\n]*\n?',
            '',
            answer_text,
            flags=re.I | re.M
        )
        # 3️⃣ NEW — remove SECTION headers anywhere (e.g. inline bleed)
        answer_text = re.sub(
            r'\bSECTION\s+[IVXLCDM]+\s*:\s*[A-Za-z ]+\b',
            '',
            answer_text,
            flags=re.I
        )
        answer_text = re.sub(r'\s+', ' ', answer_text)

        # Yes/No flag
        answer_yesno = "N/A"
        low = answer_text.lower()
        if low.startswith("yes"):
            answer_yesno = "Yes"
        elif low.startswith("no"):
            answer_yesno = "No"

        # decode any countries
        decoded = extract_countries(answer_text)

        # categorization (with Q3/Q14 → Date override)
        if q_id in ("Q3", "Q14"):
            iso = parse_single_date(answer_text)
            if iso:
                answer_text = iso
            answer_category = "Date"
        else:
            if decoded:
                answer_category = "coded_text"
            else:
                answer_category = categorize_answer(answer_text)

        # final row assembly
        row = {
            "Alliance_ID":      alliance_id,
            "Alliance_Name":    alliance_name,
            "Question_ID":      q_id,
            "Question_Short":   q_info["short"],
            "Question_Full":    q_info["full"],
            "Answer_YesNo":     answer_yesno,
            "Answer_Text":      answer_text,
            "Answer_Category":  answer_category,
            "Decoded_Countries": decoded,
            "Text_Length":      len(answer_text)
        }
        rows.append(row)

    # —————————————— Fill in any missing questions ——————————————
    found = {r["Question_ID"] for r in rows}
    for q_id, q_info in QUESTIONS.items():
        if q_id not in found:
            rows.append({
                "Alliance_ID":      alliance_id,
                "Alliance_Name":    alliance_name,
                "Question_ID":      q_id,
                "Question_Short":   q_info["short"],
                "Question_Full":    q_info["full"],
                "Answer_YesNo":     "Not Found",
                "Answer_Text":      "",
                "Answer_Category":  "Missing",
                "Decoded_Countries": "",
                "Text_Length":      0
            })

    # —————————————— Sort by question number & return ——————————————
    rows.sort(key=lambda r: int(r["Question_ID"][1:]))
    return rows


def process_single_pdf(pdf_path, alliance_id=None, alliance_name=None, save_text=False):
    """Process a single ATOP PDF file and extract data"""
    
    # Extract text from PDF
    text = extract_text_from_pdf(pdf_path)
    
    if text is None:
        print(f"Failed to extract text from {pdf_path}")
        return None
    
    # Optionally save extracted text
    if save_text:
        txt_path = Path(pdf_path).with_suffix('.txt')
        txt_path.write_text(text, encoding='utf-8')
        print(f"Text saved to: {txt_path}")
    
    # Extract alliance ID from filename if not provided
    if alliance_id is None:
        file_name = Path(pdf_path).stem
        alliance_id_match = re.search(r'ATOP(\d+)', file_name)
        alliance_id = alliance_id_match.group(1) if alliance_id_match else "Unknown"
    
    # Extract answers using fast method
    rows = fast_extract_answers(text, alliance_id, alliance_name)
    
    # Convert to DataFrame
    df = pd.DataFrame(rows)
    
    return df

def process_multiple_pdfs(pdf_paths, output_csv="atop_extracted_data.csv", save_text_files=False):
    """Process multiple ATOP PDF files and combine results"""
    
    all_dfs = []
    failed_files = []
    
    for i, pdf_path in enumerate(pdf_paths):
        print(f"\nProcessing file {i+1}/{len(pdf_paths)}: {Path(pdf_path).name}")
        
        try:
            df = process_single_pdf(pdf_path, save_text=save_text_files)
            
            if df is not None:
                all_dfs.append(df)
            else:
                failed_files.append(pdf_path)
                
        except Exception as e:
            print(f"Error processing {pdf_path}: {str(e)}")
            failed_files.append(pdf_path)
    
    # Combine all dataframes
    if all_dfs:
        combined_df = pd.concat(all_dfs, ignore_index=True)
        
        # Save to CSV
        combined_df.to_csv(output_csv, index=False)
        print(f"\n✓ Data from {len(all_dfs)} files saved to {output_csv}")
        
        if failed_files:
            print(f"\n⚠ Failed to process {len(failed_files)} files:")
            for f in failed_files:
                print(f"  - {Path(f).name}")
        
        return combined_df
    else:
        print("No data extracted from any files.")
        return None

# Example usage functions
def demo_single_pdf():
    """Demo: Process a single PDF file"""
    pdf_path = GLOBAL_SINGLE_PDF
    
    # Process the PDF
    df = process_single_pdf(
        pdf_path,
        alliance_id="1005",
        alliance_name="Quadruple Alliance",
        save_text=True  # This will also save the extracted text
    )
    
    if df is not None:
        # Display sample results
        print("\nSample extracted data:")
        print(df[['Question_ID', 'Question_Short', 'Answer_Text']].head(10))
        
        # Save to CSV
        df.to_csv("atop_1005_extracted.csv", index=False)
        print(f"\nData saved to atop_1005_extracted.csv")
        #df.head()
        return df

import glob
from pathlib import Path

def demo_batch_processing():
    """Process only ATOP PDFs that do *not* have a 'v' in their filename."""
    # 1️⃣ Glob for everything under ATOP*.pdf
    pdf_pattern = "atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets/ATOP*.pdf"
    all_pdfs = glob.glob(pdf_pattern)

    # 2️⃣ Exclude any whose stem contains 'v' (case-insensitive)
    pdf_files = [
        f for f in all_pdfs
        if 'v' not in Path(f).stem.lower()
    ]

    print(f"Found {len(pdf_files)} PDF files to process (no 'v' in filename)")

    # 3️⃣ Process as before
    combined_df = process_multiple_pdfs(
        pdf_files,
        output_csv="all_atop_data.csv",
        save_text_files=False
    )

    if combined_df is not None:
        print(f"\nTotal records extracted: {len(combined_df)}")
        print(f"Unique alliances: {combined_df['Alliance_ID'].nunique()}")


# Main execution
if __name__ == "__main__":
    # Choose one of the demo functions to run
    df = demo_batch_processing()
    print("\nProcessing complete for version 1 variant. DataFrame ready for analysis.")
# Out:
# Installing python-dateutil...
# Found 335 PDF files to process (no 'v' in filename)
#
# Processing file 1/335: ATOP1005.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1005.pdf
# ✓ Extracted 14,057 characters from ATOP1005.pdf
#
# Processing file 2/335: ATOP1020.1.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1020.1.pdf
# ✓ Extracted 11,950 characters from ATOP1020.1.pdf
#
# Processing file 3/335: ATOP1020.2.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1020.2.pdf
# ✓ Extracted 19,250 characters from ATOP1020.2.pdf
#
# Processing file 4/335: ATOP1020.3.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1020.3.pdf
# ✓ Extracted 19,147 characters from ATOP1020.3.pdf
#
# Processing file 5/335: ATOP1025.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1025.pdf
# ✓ Extracted 11,866 characters from ATOP1025.pdf
#
# Processing file 6/335: ATOP1030.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1030.pdf
# ✓ Extracted 11,765 characters from ATOP1030.pdf
#
# Processing file 7/335: ATOP1035.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1035.pdf
# ✓ Extracted 13,814 characters from ATOP1035.pdf
#
# Processing file 8/335: ATOP1040.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1040.pdf
# ✓ Extracted 12,578 characters from ATOP1040.pdf
#
# Processing file 9/335: ATOP1045.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1045.pdf
# ✓ Extracted 10,970 characters from ATOP1045.pdf
#
# Processing file 10/335: ATOP1050.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1050.pdf
# ✓ Extracted 12,143 characters from ATOP1050.pdf
#
# Processing file 11/335: ATOP1055.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1055.pdf
# ✓ Extracted 12,216 characters from ATOP1055.pdf
#
# Processing file 12/335: ATOP1060.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1060.pdf
# ✓ Extracted 10,894 characters from ATOP1060.pdf
#
# Processing file 13/335: ATOP1065.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1065.pdf
# ✓ Extracted 11,199 characters from ATOP1065.pdf
#
# Processing file 14/335: ATOP1070.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1070.pdf
# ✓ Extracted 11,575 characters from ATOP1070.pdf
#
# Processing file 15/335: ATOP1075.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP
pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4750.pdf
# ✓ Extracted 10,255 characters from ATOP4750.pdf
#
# Processing file 325/335: ATOP4755.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4755.pdf
# ✓ Extracted 9,942 characters from ATOP4755.pdf
#
# Processing file 326/335: ATOP4760.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4760.pdf
# ✓ Extracted 9,684 characters from ATOP4760.pdf
#
# Processing file 327/335: ATOP4810.1.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4810.1.pdf
# ✓ Extracted 12,229 characters from ATOP4810.1.pdf
#
# Processing file 328/335: ATOP4900.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4900.pdf
# ✓ Extracted 9,909 characters from ATOP4900.pdf
#
# Processing file 329/335: ATOP4905.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4905.pdf
# ✓ Extracted 11,839 characters from ATOP4905.pdf
#
# Processing file 330/335: ATOP4930.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4930.pdf
# ✓ Extracted 10,043 characters from ATOP4930.pdf
#
# Processing file 331/335: ATOP4953.2.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4953.2.pdf
# ✓ Extracted 23,789 characters from ATOP4953.2.pdf
#
# Processing file 332/335: ATOP4985.1.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4985.1.pdf
# ✓ Extracted 10,625 characters from ATOP4985.1.pdf
#
# Processing file 333/335: ATOP4985.2.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4985.2.pdf
# ✓ Extracted 15,839 characters from ATOP4985.2.pdf
#
# Processing file 334/335: ATOP5005.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP5005.pdf
# ✓ Extracted 11,342 characters from ATOP5005.pdf
#
# Processing file 335/335: ATOP5010.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP5010.pdf
# ✓ Extracted 10,642 characters from ATOP5010.pdf
#
# ✓ Data from 335 files saved to all_atop_data.csv
#
# Total records extracted: 20435
# Unique alliances: 323
#
# Processing complete for version 1 variant. DataFrame ready for analysis.

# %%
import re
import pandas as pd
from pathlib import Path
import sys
import subprocess
import importlib.util

GLOBAL_SINGLE_PDF = "atop_version_5.1_codesheets\ATOP Version 5.1 Codesheets\ATOP.pdf"

# Ensure required packages are installed
def ensure_package(package: str):
    """Install package if not already installed"""
    if importlib.util.find_spec(package) is None:
        print(f"Installing {package}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# Install required packages
ensure_package("pdfplumber")
ensure_package("pandas")
ensure_package("python-dateutil")       # ← add just below the others
from dateutil.parser import parse as _dt_parse



import pdfplumber

# Define all questions with exact text for faster matching
QUESTIONS = {
    "Q1": {
        "short": "ATOP_ID",
        "full": "ATOP ID",
        "question_text": "1. ATOP ID: "
    },
    "Q2": {
        "short": "COW_Alliance_Number",
        "full": "COW Alliance # (if applicable)",
        "question_text": "2. COW Alliance # (if applicable):"
    },
    "Q3": {
        "short": "Signature_Date",
        "full": "Signature date(s) (may vary for members in multilateral alliances)",
        "question_text": "3. Signature date(s) (may vary for members in multilateral alliances):"
    },
    "Q4": {
        "short": "Members",
        "full": "Members of alliance (use COW country codes)",
        "question_text": "4. Members of alliance (use COW country codes):"
    },
    "Q5": {
        "short": "Signed_During_War",
        "full": "Was the alliance signed during war? If so, which war, and which member(s) was at war?",
        "question_text": "5. Was the alliance signed during war? If so, which war, and which member(s) was at war? (check COW data)"
    },
    "Q6": {
    "short": "Establishment_Means",
    "full": (
        "Means by which alliance was established (e.g., treaty, executive agreement, "
        "diplomatic notes, etc.): (Only select \"treaty\" if the\nagreement requires "
        "ratification.)"
    ),
    # NOTE the explicit  \n  before the word “agreement” and the curly quotes
    "question_text": (
        "6. Means by which alliance was established (e.g., treaty, executive agreement, "
        "diplomatic notes, etc.): (Only select “treaty” if the\nagreement requires "
        "ratification.)"
    )
    },
    "Q7": {
        "short": "Public_Secret_Status",
        "full": "Was the treaty public, public but with secret articles, or secret?",
        "question_text": "7. Was the treaty public, public but with secret articles, or secret? If secret articles, describe the content of secret articles."
    },
    "Q8": {
        "short": "Additional_Members_Provisions",
        "full": "Are there provisions for adding additional members mentioned in the treaty?",
        "question_text": "8. Are there provisions for adding additional members mentioned in the treaty? (Yes, No) If Yes, describe these provisions."
    },
    "Q9": {
        "short": "Specific_Future_Members",
        "full": "Are specific state(s) mentioned as possible future members of the alliance?",
        "question_text": "9. Are specific state(s) mentioned as possible future members of the alliance? (Yes, No) If Yes, which state(s)?"
    },
    "Q10": {
        "short": "Treaty_Duration",
        "full": "Are there specific provisions in the treaty concerning the length of time the treaty is to last?",
        "question_text": "10. Are there specific provisions in the treaty concerning the length of time the treaty is to last? (Yes, No) If Yes, describe."
    },
    "Q11": {
        "short": "Renounce_Conditions",
        "full": "Are there conditions under which members may renounce the treaty?",
        "question_text": "11. Are there conditions under which members may renounce the treaty? If Yes, describe these conditions."
    },
    "Q12": {
        "short": "Renewal_Provisions",
        "full": "Are there specific provisions in the treaty concerning renewal of the treaty?",
        "question_text": "12. Are there specific provisions in the treaty concerning renewal of the treaty? (Yes, No) If Yes, describe these provisions."
    },
    "Q13": {
        "short": "Times_Renewed",
        "full": "Number of times alliance renewed, dates of renewal, and means by which alliance was renewed",
        "question_text": "13. Number of times alliance renewed, dates of renewal, and means by which alliance was renewed (Do not include automatic\nrenewals):"
    },
    "Q14": {
        "short": "Termination_Date",
        "full": "Termination date(s) and source(s) for termination dates(s)",
        "question_text": "14. Termination date(s) (may vary for members in multilateral alliances) and source(s) for termination dates(s):"
    },
    "Q15": {
        "short": "Termination_Cause",
        "full": "Describe what caused the alliance to terminate",
        "question_text": "15. Describe what caused the alliance to terminate."
    },
    "Q16": {
        "short": "Alliance_Type",
        "full": "Type of alliance (defense pact, neutrality pact, nonaggression pact, consultation pact, offense pact)",
        "question_text": "16. Type of alliance (defense pact, neutrality pact, nonaggression pact, consultation pact, offense pact): (List all that apply to any\nmember of the alliance.)"
    },
    "Q17": {
        "short": "COW_Alliance_Type",
        "full": "Type of alliance as coded in COW data (if applicable)",
        "question_text": "17. Type of alliance as coded in COW data (if applicable):"
    },
    "Q18": {
        "short": "Obligations",
        "full": "Describe the obligations of the alliance partners",
        "question_text": "18. Describe the obligations of the alliance partners."
    },
    "Q19": {
        "short": "Contingencies",
        "full": "Are any of the obligations contingent upon any of the following",
        "question_text": "19. Are any of the obligations contingent upon any of the following: specific adversary, specific location, specific ongoing conflict,\nnumber of adversaries, noncompliance with a specific demand, attack, nonprovocation of enemy, or prior agreement among partners?\n(List all that apply)"
    },
    "Q20": {
        "short": "Limits_Description",
        "full": "Describe the nature of the limits to obligations listed in #19",
        "question_text": "20. Describe the nature of the limits to obligations listed in #19."
    },
    "Q21": {
        "short": "Additional_War_Provisions",
        "full": "Are there any additional provisions for assistance in the event of war?",
        "question_text": "21. Are there any additional provisions for assistance in the event of war? (e.g., promise not to participate in economic sanctions against\npartner, promise not to aid internal or external enemies, etc.) (Yes, No) If Yes, describe."
    },
    "Q22": {
        "short": "Additional_Limits",
        "full": "Are there any additional limits to the alliance obligations or conditions",
        "question_text": "22. Are there any additional limits to the alliance obligations or conditions under which treaty obligations do not apply that were not\nlisted in #19? (Yes, No) If Yes, describe."
    },
    "Q23": {
        "short": "Target_Threat",
        "full": "Is a specific target/threat mentioned as the object of the treaty?",
        "question_text": "23. Is a specific target/threat mentioned as the object of the treaty? (Yes, No) (Answering Yes to this question does not necessarily mean\nthat obligations are limited only to this adversary.) If Yes, list the target nation(s) (using COW country codes if possible) and describe\nthe general nature of the reference to the target of the treaty."
    },
    "Q24": {
        "short": "Symmetric_Obligations",
        "full": "Are the treaty obligations symmetric?",
        "question_text": "24. Are the treaty obligations symmetric? (That is, do all members commit to the same obligations?) (Yes, No) If No, describe."
    },
    "Q25": {
        "short": "No_Separate_Peace",
        "full": "Does the treaty prohibit members from settling conflicts independently (no separate peace)?",
        "question_text": "25. Does the treaty prohibit members from settling conflicts independently (no separate peace)? (Yes, No) If Yes, describe."
    },
    "Q26": {
        "short": "Consult_Third_Parties",
        "full": "Does the treaty have provisions requiring that the contracting parties consult before making commitments to third parties",
        "question_text": "26. Does the treaty have provisions requiring that the contracting parties consult before making commitments to third parties (excluding\nno separate peace provisions discussed above)? (Yes, No) If Yes, describe these provisions."
    },
    "Q27": {
        "short": "No_Contrary_Alliances",
        "full": "Does the treaty specify that the contracting parties must not enter into any other alliances that are directed against the alliance",
        "question_text": "27. Does the treaty specify that the contracting parties must not enter into any other alliances that are directed against the alliance in\nquestion? (Yes, No) If Yes, describe."
    },
    "Q28": {
        "short": "Additional_Obligations_Comments",
        "full": "Additional coder comments regarding treaty obligations",
        "question_text": "28. Additional coder comments regarding treaty obligations:"
    },
    "Q29": {
        "short": "Internal_Conflict_Reference",
        "full": "Does the treaty make reference to the potential for conflict among members of the alliance?",
        "question_text": "29. Does the treaty make reference to the potential for conflict among members of the alliance? (Yes, No) If Yes, describe."
    },
    "Q30": {
        "short": "Dispute_Settlement",
        "full": "Does the treaty discuss mediation/arbitration or other means of settling disputes among the signatories?",
        "question_text": "30. Does the treaty discuss mediation/arbitration or other means of settling disputes among the signatories? (Yes, No) If Yes, describe."
    },
    "Q31": {
        "short": "Military_Contact",
        "full": "Does the treaty require official contact among the military forces of the participating states?",
        "question_text": "31. Does the treaty require official contact among the military forces of the participating states? (Yes, No) If Yes, describe. (Note\nwhether official contact is required only in the event of hostilities or also during peacetime.)"
    },
    "Q32": {
        "short": "Military_Aid",
        "full": "Does the treaty include provisions for military aid?",
        "question_text": "32. Does the treaty include provisions for military aid? (e.g., grants, loans, transfer of technology, training) (Yes, No) If Yes, describe\nthese provisions."
    },
    "Q33": {
        "short": "Integrated_Command",
        "full": "Does the treaty provide for integrated command of military forces while the alliance is in effect?",
        "question_text": "33. Does the treaty provide for integrated command of military forces while the alliance is in effect (peacetime as well as wartime)?\n(Yes, No) If Yes, describe."
    },
    "Q34": {
        "short": "Force_Subordination",
        "full": "Does the treaty require subordination of the forces of one or more member states to another in the event of hostilities?",
        "question_text": "34. Does the treaty require subordination of the forces of one or more member states to another in the event of hostilities? (Yes, No) If\nYes, describe."
    },
    "Q35": {
        "short": "Organizations_Established",
        "full": "Does the treaty establish any organizations?",
        "question_text": "35. Does the treaty establish any organizations? (include provisions for regularly scheduled meetings) (Yes, No) If Yes, describe."
    },
    "Q36": {
        "short": "Joint_Bases_Troops",
        "full": "Does the treaty provide for joint military bases, or for one or more states to place troops in the territory of one or more other states?",
        "question_text": "36. Does the treaty provide for joint military bases, or for one or more states to place troops in the territory of one or more other states?\n(Yes, No) If Yes, describe."
    },
    "Q37": {
        "short": "Contribution_Levels",
        "full": "Does the treaty specify contribution levels (funds, troops, etc.)?",
        "question_text": "37. Does the treaty specify contribution levels (funds, troops, etc.)? (Yes, No) If Yes, describe."
    },
    "Q38": {
        "short": "Armament_Provisions",
        "full": "Does the treaty contain any provisions regarding coordinated increase of armaments, reduction of armaments, prohibition of weapons, or rules of warfare?",
        "question_text": "38. Does the treaty contain any provisions regarding coordinated increase of armaments, reduction of armaments, prohibition of\nweapons, or rules of warfare? (Yes, No) If Yes, describe such provisions."
    },
    "Q39": {
        "short": "Territory_Acquisition",
        "full": "Does the treaty explicitly permit or prohibit the acquisition of territory not currently held by either ally?",
        "question_text": "39. Does the treaty explicitly permit or prohibit the acquisition of territory not currently held by either ally? (Yes, No) If Yes, describe\nreference."
    },
    "Q40": {
        "short": "Division_of_Gains",
        "full": "Does the treaty include discussion of the division of gains from any future conflict?",
        "question_text": "40. Does the treaty include discussion of the division of gains from any future conflict? (Yes, No) If Yes, describe."
    },
    "Q41": {
        "short": "Demobilization_Withdrawal",
        "full": "Does the treaty include discussion of demobilization/withdrawal following conflict?",
        "question_text": "41. Does the treaty include discussion of demobilization/withdrawal following conflict? (Yes, No) If Yes, describe."
    },
    "Q42": {
        "short": "Other_Coordination",
        "full": "Are there any other provisions in the treaty that describe the means through which the states will coordinate their military efforts and policies?",
        "question_text": "42. Are there any other provisions in the treaty that describe the means through which the states will coordinate their military efforts and\npolicies? (Yes, No) If Yes, describe."
    },
    "Q43": {
        "short": "Additional_Institutionalization_Comments",
        "full": "Additional coder comments regarding references to alliance institutionalization",
        "question_text": "43. Additional coder comments regarding references to alliance institutionalization:"
    },
    "Q44": {
        "short": "Nullifies_Treaties",
        "full": "Does the treaty state that it nullifies any existing treaties signed by one or more of the contracting parties?",
        "question_text": "44. Does the treaty state that it nullifies any existing treaties signed by one or more of the contracting parties? (Yes, No) If Yes, list the\ntreaties/agreements that are nullified and describe the treaty reference."
    },
    "Q45": {
        "short": "Modifies_Treaties",
        "full": "Does the treaty state that it modifies any existing treaties signed by one or more of the contracting parties?",
        "question_text": "45. Does the treaty state that it modifies any existing treaties signed by one or more of the contracting parties? (Yes, No) If Yes, list the\ntreaties/agreements that are modified and describe the treaty reference."
    },
    "Q46": {
        "short": "Includes_Treaties",
        "full": "Does the treaty state that it includes any existing treaties signed by one or more of the contracting parties?",
        "question_text": "46. Does the treaty state that it includes any existing treaties signed by one or more of the contracting parties? (Yes, No) If Yes, list the\ntreaties/agreements that are included and describe the treaty reference."
    },
    "Q47": {
        "short": "International_Organizations",
        "full": "Does the treaty make any references to international organizations?",
        "question_text": "47. Does the treaty make any references to international organizations? (Yes, No) If Yes, list the international organization and describe\nthe nature of the reference."
    },
    "Q48": {
        "short": "Other_Alliances",
        "full": "Does the treaty make any references to other existing alliances?",
        "question_text": "48. Does the treaty make any references to other existing alliances? (Yes, No) If Yes, list the alliance and describe the nature of the\nreference."
    },
    "Q49": {
        "short": "Companion_Agreements",
        "full": "Are there any companion agreements referenced in the treaty?",
        "question_text": "49. Are there any companion agreements referenced in the treaty? (Yes, No) If Yes, describe the agreements."
    },
    "Q50": {
        "short": "Non_Military_Cooperation",
        "full": "Does the treaty include statements regarding non-military cooperation?",
        "question_text": "50. Does the treaty include statements regarding non-military cooperation (e.g., economic, cultural, scientific exchange)? (Yes, No) If\nYes, describe."
    },
    "Q51": {
        "short": "Resolves_Conflicts",
        "full": "Does the treaty resolve other conflicts among the parties to the alliance?",
        "question_text": "51. Does the treaty resolve other conflicts among the parties to the alliance? (Yes, No) If Yes, describe."
    },
    "Q52": {
        "short": "Enforces_External_Settlement",
        "full": "Does the treaty propose/enforce settlement of a conflict not involving parties to the alliance?",
        "question_text": "52. Does the treaty propose/enforce settlement of a conflict not involving parties to the alliance? (Yes, No) If Yes, describe."
    },
    "Q53": {
        "short": "Proposes_Agreements",
        "full": "Does the treaty propose other agreements among the contracting parties?",
        "question_text": "53. Does the treaty propose other agreements among the contracting parties? (Yes, No) If Yes, describe."
    },
    "Q54": {
        "short": "Unresolved_Conflicts",
        "full": "Does the treaty mention unresolved conflicts among the contracting parties?",
        "question_text": "54. Does the treaty mention unresolved conflicts among the contracting parties? (Yes, No) If Yes, describe."
    },
    "Q55": {
        "short": "Economic_Aid",
        "full": "Does the treaty include provisions for economic aid or other enticements?",
        "question_text": "55. Does the treaty include provisions for economic aid or other enticements (include trade concessions, post war recovery, etc.)? (Yes,\nNo) If Yes, describe these provisions."
    },
    "Q56": {
        "short": "Internal_Politics_Intervention",
        "full": "Does the treaty describe circumstances under which one party may intervene in the internal politics of another party?",
        "question_text": "56. Does the treaty describe circumstances under which one party may intervene in the internal politics of another party or specifically\ncommit the states to non-intervention? (Yes, No) If Yes, describe."
    },
    "Q57": {
        "short": "Additional_Comments",
        "full": "Additional coder comments on this alliance treaty",
        "question_text": "57. Additional coder comments on this alliance treaty:"
    },
    "Q58": {
        "short": "Source_of_Coding",
        "full": "Source of coding information",
        "question_text": "58. Source of coding information (e.g., treaty, treaty and secondary sources, secondary sources only, etc.):"
    },
    "Q59": {
        "short": "Treaty_Citation",
        "full": "Treaty citation",
        "question_text": "59. Treaty citation:"
    },
    "Q60": {
        "short": "Last_Revision_Date",
        "full": "Date of last revision of this coding sheet",
        "question_text": "60. Date of last revision of this coding sheet:"
    },
    "Q61": {
        "short": "Coder",
        "full": "Coder",
        "question_text": "61. Coder:"
    }
}

def parse_single_date(text):
    """
    Return ISO date ('YYYY-MM-DD') if `text` looks like a date.
    Otherwise return None.
    """
    try:
        clean = text.strip().rstrip('.')        # drop trailing period
        dt = _dt_parse(clean, fuzzy=True)       # handles 'March 9, 1833'
        return dt.date().isoformat()
    except (ValueError, OverflowError):
        return None

def extract_countries(text):
    """
    Return a semicolon-separated string of CountryName(code) pairs found in `text`.
    Handles both '365 Russia 200 United Kingdom.' and 'Russia (365)' layouts, collecting ALL occurrences.
    """
    pairs = []

    # Pattern A – code first, then name (e.g. "365 Russia 200 United Kingdom.")
    for code, name in re.findall(
        r'\b(\d{3})\s+([A-Z][A-Za-z.\- ]+?)'               # capture 3-digit code + country name
        r'(?='                                             # but stop when you see:
          r'(?:\s+\d{3}\s)'      #   – another code (e.g. " 200 ")
          r'|[.,;\n]'            #   – or punctuation: . , ; or newline
          r'|$'                  #   – or end-of-string
        r')',
        text
    ):
        pair = f"{name.strip()}({code})"
        if pair not in pairs:
            pairs.append(pair)

    # Pattern B – name first, then code in parentheses (e.g. "Russia (365)")
    for name, code in re.findall(
        r'\b([A-Z][A-Za-z.\- ]+?)\s*\(\s*(\d{3})\s*\)',
        text
    ):
        pair = f"{name.strip()}({code})"
        if pair not in pairs:
            pairs.append(pair)

    return ";".join(pairs)





def extract_text_from_pdf(pdf_path):
    """Extract text from PDF file using pdfplumber"""
    print(f"Extracting text from {pdf_path}")
    
    try:
        with pdfplumber.open(pdf_path) as pdf:
            # Extract text from all pages
            raw_text = "\n".join(
                page.extract_text() or ""  # returns '' if page is image-only
                for page in pdf.pages
            )
        
        # Clean up multiple newlines
        raw_text_clean = re.sub(r"\n{2,}", "\n\n", raw_text)
        
        print(f"✓ Extracted {len(raw_text):,} characters from {Path(pdf_path).name}")
        return raw_text_clean
    
    except Exception as e:
        print(f"Error extracting text from {pdf_path}: {str(e)}")
        return None

def categorize_answer(answer_text):
    """Categorize the answer based on its content"""
    answer_clean = answer_text.strip()
    
    # Check for Yes/No answers
    if answer_clean.lower() in ['yes', 'no', 'yes.', 'no.', 'n/a', 'n/a.', 'zero', 'zero.']:
        return "Yes/No+Text"
    
    # Check for coded list answers (contains semicolons or specific patterns)
    if ';' in answer_clean and len(answer_clean) < 100:
        return "Coded_List"
    
    # Check for multiple items (contains "and" or comma-separated short items)
    if (',' in answer_clean or ' and ' in answer_clean.lower()) and len(answer_clean) < 100:
        return "Multiple"
    
    
    # Check for numeric answers
    if re.match(r'^\d+\.?$', answer_clean):
        return "Numeric"
    
    # Default to text for longer answers
    return "Text"

import re

def fast_extract_answers(text, alliance_id=None, alliance_name=None):
    """
    Fast extraction using whitespace-flattened search so that slight
    differences in line breaks or punctuation don’t break question matching.
    Returns a list of row dicts with keys:
      Alliance_ID, Alliance_Name, Question_ID, Question_Short, Question_Full,
      Answer_YesNo, Answer_Text, Answer_Category, Decoded_Countries, Text_Length
    """
    # —————————————— Alliance ID / Name logic (unchanged) ——————————————
    if alliance_id is None:
        id_pos = text.find("1. ATOP ID:")
        if id_pos != -1:
            start = id_pos + len("1. ATOP ID:")
            end   = text.find("\n", start)
            alliance_id = text[start:end].strip().replace("#", "").strip()
        else:
            alliance_id = "Unknown"
    if alliance_name is None:
        alliance_name = f"Alliance_{alliance_id}"

    # —————————————— Flatten for robust searching ——————————————
    text_search = re.sub(r"\s+", " ", text).strip()

    # —————————————— Locate every question position ——————————————
    question_positions = []
    for q_id, q_info in QUESTIONS.items():
        q_flat = re.sub(r"\s+", " ", q_info["question_text"]).strip()
        matches = [m.start() for m in re.finditer(re.escape(q_flat), text_search)]
        if matches:
            pos = matches[-1]
            question_positions.append((q_id, pos, len(q_flat), q_info))
    question_positions.sort(key=lambda x: x[1])

    rows = []
    # —————————————— Extract each answer block ——————————————
    for i, (q_id, pos, plen, q_info) in enumerate(question_positions):
        answer_start = pos + plen
        if i + 1 < len(question_positions):
            answer_end = question_positions[i + 1][1]
        else:
            # last question → up to common markers or end
            answer_end = len(text_search)
            for marker in ["SECTION", "Source:", "Date of last revision:"]:
                mpos = text_search.find(marker, answer_start)
                if 0 <= mpos < answer_end:
                    answer_end = mpos

        # slice & basic cleanup
        answer_text = text_search[answer_start:answer_end].strip()
        answer_text = re.sub(r'^#\s*', '', answer_text)  # drop leading "# "
        answer_text = re.sub(
            r'^See\s+#?\s*\d+\s+below[^\n]*\n?',
            '',
            answer_text,
            flags=re.I
        )
        answer_text = re.sub(
            r'^SECTION\s+[IVXLCDM]+\s*:[^\n]*\n?',
            '',
            answer_text,
            flags=re.I | re.M
        )
        # 3️⃣ NEW — remove SECTION headers anywhere (e.g. inline bleed)
        answer_text = re.sub(
            r'\bSECTION\s+[IVXLCDM]+\s*:\s*[A-Za-z ]+\b',
            '',
            answer_text,
            flags=re.I
        )
        answer_text = re.sub(r'\s+', ' ', answer_text)

        # Yes/No flag
        answer_yesno = "N/A"
        low = answer_text.lower()
        if low.startswith("yes"):
            answer_yesno = "Yes"
        elif low.startswith("no"):
            answer_yesno = "No"

        # decode any countries
        decoded = extract_countries(answer_text)

        # categorization (with Q3/Q14 → Date override)
        if q_id in ("Q3", "Q14"):
            iso = parse_single_date(answer_text)
            if iso:
                answer_text = iso
            answer_category = "Date"
        else:
            if decoded:
                answer_category = "coded_text"
            else:
                answer_category = categorize_answer(answer_text)

        # final row assembly
        row = {
            "Alliance_ID":      alliance_id,
            "Alliance_Name":    alliance_name,
            "Question_ID":      q_id,
            "Question_Short":   q_info["short"],
            "Question_Full":    q_info["full"],
            "Answer_YesNo":     answer_yesno,
            "Answer_Text":      answer_text,
            "Answer_Category":  answer_category,
            "Decoded_Countries": decoded,
            "Text_Length":      len(answer_text)
        }
        rows.append(row)

    # —————————————— Fill in any missing questions ——————————————
    found = {r["Question_ID"] for r in rows}
    for q_id, q_info in QUESTIONS.items():
        if q_id not in found:
            rows.append({
                "Alliance_ID":      alliance_id,
                "Alliance_Name":    alliance_name,
                "Question_ID":      q_id,
                "Question_Short":   q_info["short"],
                "Question_Full":    q_info["full"],
                "Answer_YesNo":     "Not Found",
                "Answer_Text":      "",
                "Answer_Category":  "Missing",
                "Decoded_Countries": "",
                "Text_Length":      0
            })

    # —————————————— Sort by question number & return ——————————————
    rows.sort(key=lambda r: int(r["Question_ID"][1:]))
    return rows


def process_single_pdf(pdf_path, alliance_id=None, alliance_name=None, save_text=False):
    """Process a single ATOP PDF file and extract data"""
    
    # Extract text from PDF
    text = extract_text_from_pdf(pdf_path)
    
    if text is None:
        print(f"Failed to extract text from {pdf_path}")
        return None
    
    # Optionally save extracted text
    if save_text:
        txt_path = Path(pdf_path).with_suffix('.txt')
        txt_path.write_text(text, encoding='utf-8')
        print(f"Text saved to: {txt_path}")
    
    # Extract alliance ID from filename if not provided
    if alliance_id is None:
        file_name = Path(pdf_path).stem
        alliance_id_match = re.search(r'ATOP(\d+)', file_name)
        alliance_id = alliance_id_match.group(1) if alliance_id_match else "Unknown"
    
    # Extract answers using fast method
    rows = fast_extract_answers(text, alliance_id, alliance_name)
    
    # Convert to DataFrame
    df = pd.DataFrame(rows)
    
    return df

def process_multiple_pdfs(pdf_paths, output_csv="atop_extracted_data.csv", save_text_files=False):
    """Process multiple ATOP PDF files and combine results"""
    
    all_dfs = []
    failed_files = []
    
    for i, pdf_path in enumerate(pdf_paths):
        print(f"\nProcessing file {i+1}/{len(pdf_paths)}: {Path(pdf_path).name}")
        
        try:
            df = process_single_pdf(pdf_path, save_text=save_text_files)
            
            if df is not None:
                all_dfs.append(df)
            else:
                failed_files.append(pdf_path)
                
        except Exception as e:
            print(f"Error processing {pdf_path}: {str(e)}")
            failed_files.append(pdf_path)
    
    # Combine all dataframes
    if all_dfs:
        combined_df = pd.concat(all_dfs, ignore_index=True)
        
        # Save to CSV
        combined_df.to_csv(output_csv, index=False)
        print(f"\n✓ Data from {len(all_dfs)} files saved to {output_csv}")
        
        if failed_files:
            print(f"\n⚠ Failed to process {len(failed_files)} files:")
            for f in failed_files:
                print(f"  - {Path(f).name}")
        
        return combined_df
    else:
        print("No data extracted from any files.")
        return None

# Example usage functions
def demo_single_pdf():
    """Demo: Process a single PDF file"""
    pdf_path = GLOBAL_SINGLE_PDF
    
    # Process the PDF
    df = process_single_pdf(
        pdf_path,
        alliance_id="1005",
        alliance_name="Quadruple Alliance",
        save_text=True  # This will also save the extracted text
    )
    
    if df is not None:
        # Display sample results
        print("\nSample extracted data:")
        print(df[['Question_ID', 'Question_Short', 'Answer_Text']].head(10))
        
        # Save to CSV
        df.to_csv("atop_1005_extracted.csv", index=False)
        print(f"\nData saved to atop_1005_extracted.csv")
        #df.head()
        return df

import glob
from pathlib import Path


def demo_v4_processing():
    """Process only ATOP PDFs whose filenames end with 'v4' (case-insensitive)."""
    # 1️⃣ Glob for everything under ATOP*.pdf
    pdf_pattern = "atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets/ATOP*.pdf"
    all_pdfs = glob.glob(pdf_pattern)

    # 2️⃣ Keep only those whose stem ends with 'v4'
    v4_pdfs = [
        f for f in all_pdfs
        if Path(f).stem.lower().endswith("v4")
    ]

    print(f"Found {len(v4_pdfs)} ATOP v4 PDF files to process")

    # 3️⃣ Process just the v4 files
    combined_df = process_multiple_pdfs(
        v4_pdfs,
        output_csv="all_atop_v4_data.csv",
        save_text_files=False
    )

    if combined_df is not None:
        print(f"\nTotal records extracted from v4 files: {len(combined_df)}")
        print(f"Unique alliances in v4 set: {combined_df['Alliance_ID'].nunique()}")



# Main execution
if __name__ == "__main__":

    # Choose one of the demo functions to run
    # df = demo_single_pdf()
    demo_v4_processing()
    print("\nProcessing complete for version 4 variant. DataFrame ready for analysis.")
# Out:
# Installing python-dateutil...
# Found 409 ATOP v4 PDF files to process
#
# Processing file 1/409: ATOP1010v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1010v4.pdf
# ✓ Extracted 11,395 characters from ATOP1010v4.pdf
#
# Processing file 2/409: ATOP1015v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1015v4.pdf
# ✓ Extracted 10,370 characters from ATOP1015v4.pdf
#
# Processing file 3/409: ATOP1053v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1053v4.pdf
# ✓ Extracted 10,780 characters from ATOP1053v4.pdf
#
# Processing file 4/409: ATOP1145v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1145v4.pdf
# ✓ Extracted 11,017 characters from ATOP1145v4.pdf
#
# Processing file 5/409: ATOP1150v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1150v4.pdf
# ✓ Extracted 13,266 characters from ATOP1150v4.pdf
#
# Processing file 6/409: ATOP1155.2v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1155.2v4.pdf
# ✓ Extracted 10,450 characters from ATOP1155.2v4.pdf
#
# Processing file 7/409: ATOP1235v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1235v4.pdf
# ✓ Extracted 11,068 characters from ATOP1235v4.pdf
#
# Processing file 8/409: ATOP1415.2v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1415.2v4.pdf
# ✓ Extracted 14,216 characters from ATOP1415.2v4.pdf
#
# Processing file 9/409: ATOP1430v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1430v4.pdf
# ✓ Extracted 11,876 characters from ATOP1430v4.pdf
#
# Processing file 10/409: ATOP1465v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1465v4.pdf
# ✓ Extracted 9,636 characters from ATOP1465v4.pdf
#
# Processing file 11/409: ATOP1467v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1467v4.pdf
# ✓ Extracted 10,942 characters from ATOP1467v4.pdf
#
# Processing file 12/409: ATOP1480v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1480v4.pdf
# ✓ Extracted 12,523 characters from ATOP1480v4.pdf
#
# Processing file 13/409: ATOP2020v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2020v4.pdf
# ✓ Extracted 11,330 characters from ATOP2020v4.pdf
#
# Processing file 14/409: ATOP2045v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2045v4.pdf
# ✓ Extracted 11,126 characters from ATOP2045v4.pdf
#
# Processing file 15/409: ATOP2090v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2090v4.pdf
# ✓ Extracted 9,728 characters from ATOP2090v4.pdf
#
# Processing file 16/409: ATOP2105v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2105v4.pdf
# ✓ Extracted 12,460 characters from ATOP2105v4.pdf
#
# Processing file 17/409: ATOP2130v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2130v4.pdf
# ✓ Extracted 12,901 characters from ATOP2130v4.pdf
#
# Processing file 18/409: ATOP2155.2v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2155.2v4.pdf
# ✓ Extracted 13,191 characters from ATOP2155.2v4.pdf
#
# Processing file 19/409: ATOP2185v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2185v4.pdf
# ✓ Extracted 11,607 characters from ATOP2185v4.pdf
#
# Processing file 20/409: ATOP2210v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2210v4.pdf
# ✓ Extracted 15,004 characters from ATOP2210v4.pdf
#
# Processing file 21/409: ATOP2270v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2270v4.pdf
# ✓ Extracted 13,555 characters from ATOP2270v4.pdf
#
# Processing file 22/409: ATOP2285v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2285v4.pdf
# ✓ Extracted 11,491 characters from ATOP2285v4.pdf
#
# Processing file 23/409: ATOP2290v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2290v4.pdf
# ✓ Extracted 12,225 characters from ATOP2290v4.pdf
#
# Processing file 24/409: ATOP2340.2v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2340.2v4.pdf
# ✓ Extracted 16,394 characters from ATOP2340.2v4.pdf
#
# Processing file 25/409: ATOP2370v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2370v4.pdf
# ✓ Extracted 10,123 characters from ATOP2370v4.pdf
#
# Processing file 26/409: ATOP2410v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2410v4.pdf
# ✓ Extracted 11,751 characters from ATOP2410v4.pdf
#
# Processing file 27/409: ATOP2415v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2415v4.pdf
# ✓ Extracted 10,706 characters from ATOP2415v4.pdf
#
# Processing file 28/409: ATOP2465v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2465v4.pdf
# ✓ Extracted 10,313 characters from ATOP2465v4.pdf
#
# Processing file 29/409: ATOP2485v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2485v4.pdf
# ✓ Extracted 12,024 characters from ATOP2485v4.pdf
#
# Processing file 30/409: ATOP2490v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2490v4.pdf
# ✓ Extracted 13,993 characters from ATOP2490v4.pdf
#
# Processing file 31/409: ATOP2495v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2495v4.pdf
# ✓ Extracted 12,097 characters from ATOP2495v4.pdf
#
# Processing file 32/409: ATOP2510v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2510v4.pdf
# ✓ Extracted 9,373 characters from ATOP2510v4.pdf
#
# Processing file 33/409: ATOP2515v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2515v4.pdf
# ✓ Extracted 12,137 characters from ATOP2515v4.pdf
#
# Processing file 34/409: ATOP2563v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2563v4.pdf
# ✓ Extracted 11,276 characters from ATOP2563v4.pdf
#
# Processing file 35/409: ATOP2565v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP2565v4.pdf
# ✓ Extracted 12,670 characters from ATOP2565v4.pdf
#
# Processing file 36/409: ATOP3015v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3015v4.pdf
# ✓ Extracted 14,790 characters from ATOP3015v4.pdf
#
# Processing file 37/409: ATOP3025v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3025v4.pdf
# ✓ Extracted 11,009 characters from ATOP3025v4.pdf
#
# Processing file 38/409: ATOP3030v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3030v4.pdf
# ✓ Extracted 12,581 characters from ATOP3030v4.pdf
#
# Processing file 39/409: ATOP3040v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3040v4.pdf
# ✓ Extracted 11,117 characters from ATOP3040v4.pdf
#
# Processing file 40/409: ATOP3055v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3055v4.pdf
# ✓ Extracted 11,599 characters from ATOP3055v4.pdf
#
# Processing file 41/409: ATOP3060v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3060v4.pdf
# ✓ Extracted 10,719 characters from ATOP3060v4.pdf
#
# Processing file 42/409: ATOP3075v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3075v4.pdf
# ✓ Extracted 14,478 characters from ATOP3075v4.pdf
#
# Processing file 43/409: ATOP3077v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3077v4.pdf
# ✓ Extracted 11,145 characters from ATOP3077v4.pdf
#
# Processing file 44/409: ATOP3105v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3105v4.pdf
# ✓ Extracted 11,454 characters from ATOP3105v4.pdf
#
# Processing file 45/409: ATOP3110v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3110v4.pdf
# ✓ Extracted 10,590 characters from ATOP3110v4.pdf
#
# Processing file 46/409: ATOP3115v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3115v4.pdf
# ✓ Extracted 10,667 characters from ATOP3115v4.pdf
#
# Processing file 47/409: ATOP3120v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3120v4.pdf
# ✓ Extracted 10,548 characters from ATOP3120v4.pdf
#
# Processing file 48/409: ATOP3130.2v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3130.2v4.pdf
# ✓ Extracted 15,061 characters from ATOP3130.2v4.pdf
#
# Processing file 49/409: ATOP3135v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3135v4.pdf
# ✓ Extracted 10,612 characters from ATOP3135v4.pdf
#
# Processing file 50/409: ATOP3140v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3140v4.pdf
# ✓ Extracted 11,257 characters from ATOP3140v4.pdf
#
# Processing file 51/409: ATOP3145v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3145v4.pdf
# ✓ Extracted 10,610 characters from ATOP3145v4.pdf
#
# Processing file 52/409: ATOP3150v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3150v4.pdf
# ✓ Extracted 13,602 characters from ATOP3150v4.pdf
#
# Processing file 53/409: ATOP3155v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3155v4.pdf
# ✓ Extracted 10,708 characters from ATOP3155v4.pdf
#
# Processing file 54/409: ATOP3160v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3160v4.pdf
# ✓ Extracted 10,503 characters from ATOP3160v4.pdf
#
# Processing file 55/409: ATOP3165v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3165v4.pdf
# ✓ Extracted 10,599 characters from ATOP3165v4.pdf
#
# Processing file 56/409: ATOP3170v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3170v4.pdf
# ✓ Extracted 10,388 characters from ATOP3170v4.pdf
#
# Processing file 57/409: ATOP3175v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3175v4.pdf
# ✓ Extracted 10,526 characters from ATOP3175v4.pdf
#
# Processing file 58/409: ATOP3180v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3180v4.pdf
# ✓ Extracted 14,032 characters from ATOP3180v4.pdf
#
# Processing file 59/409: ATOP3185v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3185v4.pdf
# ✓ Extracted 10,412 characters from ATOP3185v4.pdf
#
# Processing file 60/409: ATOP3190v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3190v4.pdf
# ✓ Extracted 10,399 characters from ATOP3190v4.pdf
#
# Processing file 61/409: ATOP3195v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3195v4.pdf
# ✓ Extracted 10,622 characters from ATOP3195v4.pdf
#
# Processing file 62/409: ATOP3205v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3205v4.pdf
# ✓ Extracted 14,674 characters from ATOP3205v4.pdf
#
# Processing file 63/409: ATOP3210v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3210v4.pdf
# ✓ Extracted 10,825 characters from ATOP3210v4.pdf
#
# Processing file 64/409: ATOP3215v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3215v4.pdf
# ✓ Extracted 11,532 characters from ATOP3215v4.pdf
#
# Processing file 65/409: ATOP3220v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3220v4.pdf
# ✓ Extracted 12,752 characters from ATOP3220v4.pdf
#
# Processing file 66/409: ATOP3225v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3225v4.pdf
# ✓ Extracted 11,120 characters from ATOP3225v4.pdf
#
# Processing file 67/409: ATOP3228v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3228v4.pdf
# ✓ Extracted 11,389 characters from ATOP3228v4.pdf
#
# Processing file 68/409: ATOP3240v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3240v4.pdf
# ✓ Extracted 11,395 characters from ATOP3240v4.pdf
#
# Processing file 69/409: ATOP3250v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3250v4.pdf
# ✓ Extracted 10,936 characters from ATOP3250v4.pdf
#
# Processing file 70/409: ATOP3255v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3255v4.pdf
# ✓ Extracted 11,926 characters from ATOP3255v4.pdf
#
# Processing file 71/409: ATOP3260.2v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3260.2v4.pdf
# ✓ Extracted 13,376 characters from ATOP3260.2v4.pdf
#
# Processing file 72/409: ATOP3295v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3295v4.pdf
# ✓ Extracted 12,170 characters from ATOP3295v4.pdf
#
# Processing file 73/409: ATOP3320v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3320v4.pdf
# ✓ Extracted 10,150 characters from ATOP3320v4.pdf
#
# Processing file 74/409: ATOP3335v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3335v4.pdf
# ✓ Extracted 10,742 characters from ATOP3335v4.pdf
#
# Processing file 75/409: ATOP3355v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3355v4.pdf
# ✓ Extracted 10,414 characters from ATOP3355v4.pdf
#
# Processing file 76/409: ATOP3360v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3360v4.pdf
# ✓ Extracted 10,400 characters from ATOP3360v4.pdf
#
# Processing file 77/409: ATOP3370v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3370v4.pdf
# ✓ Extracted 10,107 characters from ATOP3370v4.pdf
#
# Processing file 78/409: ATOP3375v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3375v4.pdf
# ✓ Extracted 11,853 characters from ATOP3375v4.pdf
#
# Processing file 79/409: ATOP3395v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3395v4.pdf
# ✓ Extracted 11,842 characters from ATOP3395v4.pdf
#
# Processing file 80/409: ATOP3410v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3410v4.pdf
# ✓ Extracted 11,089 characters from ATOP3410v4.pdf
#
# Processing file 81/409: ATOP3415v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3415v4.pdf
# ✓ Extracted 10,134 characters from ATOP3415v4.pdf
#
# Processing file 82/409: ATOP3420v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3420v4.pdf
# ✓ Extracted 10,498 characters from ATOP3420v4.pdf
#
# Processing file 83/409: ATOP3445v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3445v4.pdf
# ✓ Extracted 10,989 characters from ATOP3445v4.pdf
#
# Processing file 84/409: ATOP3450v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3450v4.pdf
# ✓ Extracted 10,213 characters from ATOP3450v4.pdf
#
# Processing file 85/409: ATOP3470v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3470v4.pdf
# ✓ Extracted 11,450 characters from ATOP3470v4.pdf
#
# Processing file 86/409: ATOP3475v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3475v4.pdf
# ✓ Extracted 11,070 characters from ATOP3475v4.pdf
#
# Processing file 87/409: ATOP3480v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3480v4.pdf
# ✓ Extracted 14,208 characters from ATOP3480v4.pdf
#
# Processing file 88/409: ATOP3510v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3510v4.pdf
# ✓ Extracted 10,273 characters from ATOP3510v4.pdf
#
# Processing file 89/409: ATOP3515v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3515v4.pdf
# ✓ Extracted 10,252 characters from ATOP3515v4.pdf
#
# Processing file 90/409: ATOP3535v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3535v4.pdf
# ✓ Extracted 10,139 characters from ATOP3535v4.pdf
#
# Processing file 91/409: ATOP3540v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3540v4.pdf
# ✓ Extracted 10,387 characters from ATOP3540v4.pdf
#
# Processing file 92/409: ATOP3545v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3545v4.pdf
# ✓ Extracted 10,729 characters from ATOP3545v4.pdf
#
# Processing file 93/409: ATOP3550v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3550v4.pdf
# ✓ Extracted 10,291 characters from ATOP3550v4.pdf
#
# Processing file 94/409: ATOP3555v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3555v4.pdf
# ✓ Extracted 10,087 characters from ATOP3555v4.pdf
#
# Processing file 95/409: ATOP3560v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3560v4.pdf
# ✓ Extracted 10,932 characters from ATOP3560v4.pdf
#
# Processing file 96/409: ATOP3565v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3565v4.pdf
# ✓ Extracted 10,462 characters from ATOP3565v4.pdf
#
# Processing file 97/409: ATOP3575v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3575v4.pdf
# ✓ Extracted 10,798 characters from ATOP3575v4.pdf
#
# Processing file 98/409: ATOP3580v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3580v4.pdf
# ✓ Extracted 10,831 characters from ATOP3580v4.pdf
#
# Processing file 99/409: ATOP3595v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3595v4.pdf
# ✓ Extracted 10,143 characters from ATOP3595v4.pdf
#
# Processing file 100/409: ATOP3600v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3600v4.pdf
# ✓ Extracted 10,146 characters from ATOP3600v4.pdf
#
# Processing file 101/409: ATOP3610v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3610v4.pdf
# ✓ Extracted 10,774 characters from ATOP3610v4.pdf
#
# Processing file 102/409: ATOP3623v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3623v4.pdf
# ✓ Extracted 10,691 characters from ATOP3623v4.pdf
#
# Processing file 103/409: ATOP3625v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3625v4.pdf
# ✓ Extracted 11,071 characters from ATOP3625v4.pdf
#
# Processing file 104/409: ATOP3635v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3635v4.pdf
# ✓ Extracted 11,440 characters from ATOP3635v4.pdf
#
# Processing file 105/409: ATOP3640v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3640v4.pdf
# ✓ Extracted 9,535 characters from ATOP3640v4.pdf
#
# Processing file 106/409: ATOP3642v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3642v4.pdf
# ✓ Extracted 9,733 characters from ATOP3642v4.pdf
#
# Processing file 107/409: ATOP3645v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3645v4.pdf
# ✓ Extracted 10,802 characters from ATOP3645v4.pdf
#
# Processing file 108/409: ATOP3650v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3650v4.pdf
# ✓ Extracted 10,602 characters from ATOP3650v4.pdf
#
# Processing file 109/409: ATOP3655v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3655v4.pdf
# ✓ Extracted 9,853 characters from ATOP3655v4.pdf
#
# Processing file 110/409: ATOP3665v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3665v4.pdf
# ✓ Extracted 9,932 characters from ATOP3665v4.pdf
#
# Processing file 111/409: ATOP3675v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3675v4.pdf
# ✓ Extracted 12,141 characters from ATOP3675v4.pdf
#
# Processing file 112/409: ATOP3680v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3680v4.pdf
# ✓ Extracted 10,485 characters from ATOP3680v4.pdf
#
# Processing file 113/409: ATOP3705v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3705v4.pdf
# ✓ Extracted 11,317 characters from ATOP3705v4.pdf
#
# Processing file 114/409: ATOP3720v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3720v4.pdf
# ✓ Extracted 10,410 characters from ATOP3720v4.pdf
#
# Processing file 115/409: ATOP3730v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3730v4.pdf
# ✓ Extracted 10,441 characters from ATOP3730v4.pdf
#
# Processing file 116/409: ATOP3740v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3740v4.pdf
# ✓ Extracted 13,566 characters from ATOP3740v4.pdf
#
# Processing file 117/409: ATOP3743v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3743v4.pdf
# ✓ Extracted 10,742 characters from ATOP3743v4.pdf
#
# Processing file 118/409: ATOP3755v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3755v4.pdf
# ✓ Extracted 12,147 characters from ATOP3755v4.pdf
#
# Processing file 119/409: ATOP3760v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3760v4.pdf
# ✓ Extracted 9,496 characters from ATOP3760v4.pdf
#
# Processing file 120/409: ATOP3765v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3765v4.pdf
# ✓ Extracted 11,180 characters from ATOP3765v4.pdf
#
# Processing file 121/409: ATOP3775v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3775v4.pdf
# ✓ Extracted 11,554 characters from ATOP3775v4.pdf
#
# Processing file 122/409: ATOP3790v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3790v4.pdf
# ✓ Extracted 11,360 characters from ATOP3790v4.pdf
#
# Processing file 123/409: ATOP3810v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3810v4.pdf
# ✓ Extracted 11,814 characters from ATOP3810v4.pdf
#
# Processing file 124/409: ATOP3815v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3815v4.pdf
# ✓ Extracted 10,628 characters from ATOP3815v4.pdf
#
# Processing file 125/409: ATOP3820v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3820v4.pdf
# ✓ Extracted 11,451 characters from ATOP3820v4.pdf
#
# Processing file 126/409: ATOP3825v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3825v4.pdf
# ✓ Extracted 10,181 characters from ATOP3825v4.pdf
#
# Processing file 127/409: ATOP3830v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3830v4.pdf
# ✓ Extracted 10,144 characters from ATOP3830v4.pdf
#
# Processing file 128/409: ATOP3841v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3841v4.pdf
# ✓ Extracted 9,470 characters from ATOP3841v4.pdf
#
# Processing file 129/409: ATOP3842v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3842v4.pdf
# ✓ Extracted 10,092 characters from ATOP3842v4.pdf
#
# Processing file 130/409: ATOP3843v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3843v4.pdf
# ✓ Extracted 9,298 characters from ATOP3843v4.pdf
#
# Processing file 131/409: ATOP3850v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3850v4.pdf
# ✓ Extracted 11,165 characters from ATOP3850v4.pdf
#
# Processing file 132/409: ATOP3851v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3851v4.pdf
# ✓ Extracted 10,809 characters from ATOP3851v4.pdf
#
# Processing file 133/409: ATOP3852v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3852v4.pdf
# ✓ Extracted 10,950 characters from ATOP3852v4.pdf
#
# Processing file 134/409: ATOP3875v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3875v4.pdf
# ✓ Extracted 10,934 characters from ATOP3875v4.pdf
#
# Processing file 135/409: ATOP3885v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3885v4.pdf
# ✓ Extracted 10,758 characters from ATOP3885v4.pdf
#
# Processing file 136/409: ATOP3887v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3887v4.pdf
# ✓ Extracted 10,368 characters from ATOP3887v4.pdf
#
# Processing file 137/409: ATOP3890v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3890v4.pdf
# ✓ Extracted 11,014 characters from ATOP3890v4.pdf
#
# Processing file 138/409: ATOP3895v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3895v4.pdf
# ✓ Extracted 12,971 characters from ATOP3895v4.pdf
#
# Processing file 139/409: ATOP3900v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3900v4.pdf
# ✓ Extracted 14,190 characters from ATOP3900v4.pdf
#
# Processing file 140/409: ATOP3915v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3915v4.pdf
# ✓ Extracted 10,614 characters from ATOP3915v4.pdf
#
# Processing file 141/409: ATOP3948v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3948v4.pdf
# ✓ Extracted 11,465 characters from ATOP3948v4.pdf
#
# Processing file 142/409: ATOP3952v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3952v4.pdf
# ✓ Extracted 9,920 characters from ATOP3952v4.pdf
#
# Processing file 143/409: ATOP3965v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3965v4.pdf
# ✓ Extracted 10,060 characters from ATOP3965v4.pdf
#
# Processing file 144/409: ATOP3973v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3973v4.pdf
# ✓ Extracted 11,372 characters from ATOP3973v4.pdf
#
# Processing file 145/409: ATOP3975v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3975v4.pdf
# ✓ Extracted 9,757 characters from ATOP3975v4.pdf
#
# Processing file 146/409: ATOP3980v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3980v4.pdf
# ✓ Extracted 10,564 characters from ATOP3980v4.pdf
#
# Processing file 147/409: ATOP3984v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3984v4.pdf
# ✓ Extracted 12,383 characters from ATOP3984v4.pdf
#
# Processing file 148/409: ATOP3995v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3995v4.pdf
# ✓ Extracted 11,521 characters from ATOP3995v4.pdf
#
# Processing file 149/409: ATOP4005v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4005v4.pdf
# ✓ Extracted 12,045 characters from ATOP4005v4.pdf
#
# Processing file 150/409: ATOP4010v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4010v4.pdf
# ✓ Extracted 11,636 characters from ATOP4010v4.pdf
#
# Processing file 151/409: ATOP4015v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4015v4.pdf
# ✓ Extracted 11,540 characters from ATOP4015v4.pdf
#
# Processing file 152/409: ATOP4020v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4020v4.pdf
# ✓ Extracted 10,867 characters from ATOP4020v4.pdf
#
# Processing file 153/409: ATOP4022v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4022v4.pdf
# ✓ Extracted 12,480 characters from ATOP4022v4.pdf
#
# Processing file 154/409: ATOP4023v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4023v4.pdf
# ✓ Extracted 12,539 characters from ATOP4023v4.pdf
#
# Processing file 155/409: ATOP4025v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4025v4.pdf
# ✓ Extracted 11,121 characters from ATOP4025v4.pdf
#
# Processing file 156/409: ATOP4035v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4035v4.pdf
# ✓ Extracted 11,517 characters from ATOP4035v4.pdf
#
# Processing file 157/409: ATOP4040v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP
4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6015v4.pdf
# ✓ Extracted 13,080 characters from ATOP6015v4.pdf
#
# Processing file 401/409: ATOP6020v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6020v4.pdf
# ✓ Extracted 12,204 characters from ATOP6020v4.pdf
#
# Processing file 402/409: ATOP6025v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6025v4.pdf
# ✓ Extracted 11,197 characters from ATOP6025v4.pdf
#
# Processing file 403/409: ATOP6030v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6030v4.pdf
# ✓ Extracted 12,627 characters from ATOP6030v4.pdf
#
# Processing file 404/409: ATOP6035v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6035v4.pdf
# ✓ Extracted 16,369 characters from ATOP6035v4.pdf
#
# Processing file 405/409: ATOP6040v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6040v4.pdf
# ✓ Extracted 12,834 characters from ATOP6040v4.pdf
#
# Processing file 406/409: ATOP6045v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6045v4.pdf
# ✓ Extracted 16,702 characters from ATOP6045v4.pdf
#
# Processing file 407/409: ATOP6050v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6050v4.pdf
# ✓ Extracted 16,942 characters from ATOP6050v4.pdf
#
# Processing file 408/409: ATOP6055v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6055v4.pdf
# ✓ Extracted 11,344 characters from ATOP6055v4.pdf
#
# Processing file 409/409: ATOP6060v4.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6060v4.pdf
# ✓ Extracted 13,572 characters from ATOP6060v4.pdf
#
# ✓ Data from 409 files saved to all_atop_v4_data.csv
#
# Total records extracted from v4 files: 24949
# Unique alliances in v4 set: 405
#
# Processing complete for version 4 variant. DataFrame ready for analysis.

# %%
import re
import pandas as pd
from pathlib import Path
import sys
import subprocess
import importlib.util

GLOBAL_SINGLE_PDF = "atop_version_5.1_codesheets\ATOP Version 5.1 Codesheets\ATOP7050v5.pdf"

# Ensure required packages are installed
def ensure_package(package: str):
    """Install package if not already installed"""
    if importlib.util.find_spec(package) is None:
        print(f"Installing {package}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# Install required packages
ensure_package("pdfplumber")
ensure_package("pandas")
ensure_package("python-dateutil")       # ← add just below the others
from dateutil.parser import parse as _dt_parse



import pdfplumber

# Define all questions with exact text for faster matching
QUESTIONS = {
    "Q1": {
        "short": "ATOP_ID",
        "full": "ATOP ID",
        "question_text": "1. ATOP ID: "
    },
    "Q2": {
        "short": "COW_Alliance_Number",
        "full": "COW Alliance # (if applicable)",
        "question_text": "2. COW Alliance # (if applicable):"
    },
    "Q3": {
        "short": "Signature_Date",
        "full": "Signature date(s) (may vary for members in multilateral alliances)",
        "question_text": "3. Signature date(s) (may vary for members in multilateral alliances):"
    },
    "Q4": {
        "short": "Members",
        "full": "Members of alliance (use COW country codes)",
        "question_text": "4. Members of alliance (use COW country codes):"
    },
    "Q5": {
        "short": "Signed_During_War",
        "full": "Was the alliance signed during war? If so, which war, and which member(s) was at war?",
        "question_text": "5. Was the alliance signed during war? If so, which war, and which member(s) was at war? (check COW data)"
    },
    "Q6": {
    "short": "Establishment_Means",
    "full": (
        "Means by which alliance was established (e.g., treaty, executive agreement, "
        "diplomatic notes, etc.): (Only select \"treaty\" if the\nagreement requires "
        "ratification.)"
    ),
    # NOTE the explicit  \n  before the word “agreement” and the curly quotes
    "question_text": (
        "6. Means by which alliance was established (e.g., treaty, executive agreement, "
        "diplomatic notes, etc.): (Only select “treaty” if the\nagreement requires "
        "ratification.)"
    )
    },
    "Q7": {
        "short": "Public_Secret_Status",
        "full": "Was the treaty public, public but with secret articles, or secret?",
        "question_text": "7. Was the treaty public, public but with secret articles, or secret? If secret articles, describe the content of secret articles."
    },
    "Q8": {
        "short": "Additional_Members_Provisions",
        "full": "Are there provisions for adding additional members mentioned in the treaty?",
        "question_text": "8. Are there provisions for adding additional members mentioned in the treaty? (Yes, No) If Yes, describe these provisions."
    },
    "Q9": {
        "short": "Specific_Future_Members",
        "full": "Are specific state(s) mentioned as possible future members of the alliance?",
        "question_text": "9. Are specific state(s) mentioned as possible future members of the alliance? (Yes, No) If Yes, which state(s)?"
    },
    "Q10": {
        "short": "Treaty_Duration",
        "full": "Are there specific provisions in the treaty concerning the length of time the treaty is to last?",
        "question_text": "10. Are there specific provisions in the treaty concerning the length of time the treaty is to last? (Yes, No) If Yes, describe."
    },
    "Q11": {
        "short": "Renounce_Conditions",
        "full": "Are there conditions under which members may renounce the treaty?",
        "question_text": "11. Are there conditions under which members may renounce the treaty? If Yes, describe these conditions."
    },
    "Q12": {
        "short": "Renewal_Provisions",
        "full": "Are there specific provisions in the treaty concerning renewal of the treaty?",
        "question_text": "12. Are there specific provisions in the treaty concerning renewal of the treaty? (Yes, No) If Yes, describe these provisions."
    },
    "Q13": {
        "short": "Times_Renewed",
        "full": "Number of times alliance renewed, dates of renewal, and means by which alliance was renewed",
        "question_text": "13. Number of times alliance renewed, dates of renewal, and means by which alliance was renewed (Do not include automatic\nrenewals):"
    },
    "Q14": {
        "short": "Termination_Date",
        "full": "Termination date(s) and source(s) for termination dates(s)",
        "question_text": "14. Termination date(s) (may vary for members in multilateral alliances) and source(s) for termination dates(s):"
    },
    "Q15": {
        "short": "Termination_Cause",
        "full": "Describe what caused the alliance to terminate",
        "question_text": "15. Describe what caused the alliance to terminate."
    },
    "Q16": {
        "short": "Alliance_Type",
        "full": "Type of alliance (defense pact, neutrality pact, nonaggression pact, consultation pact, offense pact)",
        "question_text": "16. Type of alliance (defense pact, neutrality pact, nonaggression pact, consultation pact, offense pact): (List all that apply to any\nmember of the alliance.)"
    },
    "Q17": {
        "short": "COW_Alliance_Type",
        "full": "Type of alliance as coded in COW data (if applicable)",
        "question_text": "17. Type of alliance as coded in COW data (if applicable):"
    },
    "Q18": {
        "short": "Obligations",
        "full": "Describe the obligations of the alliance partners",
        "question_text": "18. Describe the obligations of the alliance partners."
    },
    "Q19": {
        "short": "Contingencies",
        "full": "Are any of the obligations contingent upon any of the following",
        "question_text": "19. Are any of the obligations contingent upon any of the following: specific adversary, specific location, specific ongoing conflict,\nnumber of adversaries, noncompliance with a specific demand, attack, nonprovocation of enemy, or prior agreement among partners?\n(List all that apply)"
    },
    "Q20": {
        "short": "Limits_Description",
        "full": "Describe the nature of the limits to obligations listed in #19",
        "question_text": "20. Describe the nature of the limits to obligations listed in #19."
    },
    "Q21": {
        "short": "Additional_War_Provisions",
        "full": "Are there any additional provisions for assistance in the event of war?",
        "question_text": "21. Are there any additional provisions for assistance in the event of war? (e.g., promise not to participate in economic sanctions against\npartner, promise not to aid internal or external enemies, etc.) (Yes, No) If Yes, describe."
    },
    "Q22": {
        "short": "Additional_Limits",
        "full": "Are there any additional limits to the alliance obligations or conditions",
        "question_text": "22. Are there any additional limits to the alliance obligations or conditions under which treaty obligations do not apply that were not\nlisted in #19? (Yes, No) If Yes, describe."
    },
    "Q23": {
        "short": "Target_Threat",
        "full": "Is a specific target/threat mentioned as the object of the treaty?",
        "question_text": "23. Is a specific target/threat mentioned as the object of the treaty? (Yes, No) (Answering Yes to this question does not necessarily mean\nthat obligations are limited only to this adversary.) If Yes, list the target nation(s) (using COW country codes if possible) and describe\nthe general nature of the reference to the target of the treaty."
    },
    "Q24": {
        "short": "Symmetric_Obligations",
        "full": "Are the treaty obligations symmetric?",
        "question_text": "24. Are the treaty obligations symmetric? (That is, do all members commit to the same obligations?) (Yes, No) If No, describe."
    },
    "Q25": {
        "short": "No_Separate_Peace",
        "full": "Does the treaty prohibit members from settling conflicts independently (no separate peace)?",
        "question_text": "25. Does the treaty prohibit members from settling conflicts independently (no separate peace)? (Yes, No) If Yes, describe."
    },
    "Q26": {
        "short": "Consult_Third_Parties",
        "full": "Does the treaty have provisions requiring that the contracting parties consult before making commitments to third parties",
        "question_text": "26. Does the treaty have provisions requiring that the contracting parties consult before making commitments to third parties (excluding\nno separate peace provisions discussed above)? (Yes, No) If Yes, describe these provisions."
    },
    "Q27": {
        "short": "No_Contrary_Alliances",
        "full": "Does the treaty specify that the contracting parties must not enter into any other alliances that are directed against the alliance",
        "question_text": "27. Does the treaty specify that the contracting parties must not enter into any other alliances that are directed against the alliance in\nquestion? (Yes, No) If Yes, describe."
    },
    "Q28": {
        "short": "Additional_Obligations_Comments",
        "full": "Additional coder comments regarding treaty obligations",
        "question_text": "28. Additional coder comments regarding treaty obligations:"
    },
    "Q29": {
        "short": "Internal_Conflict_Reference",
        "full": "Does the treaty make reference to the potential for conflict among members of the alliance?",
        "question_text": "29. Does the treaty make reference to the potential for conflict among members of the alliance? (Yes, No) If Yes, describe."
    },
    "Q30": {
        "short": "Dispute_Settlement",
        "full": "Does the treaty discuss mediation/arbitration or other means of settling disputes among the signatories?",
        "question_text": "30. Does the treaty discuss mediation/arbitration or other means of settling disputes among the signatories? (Yes, No) If Yes, describe."
    },
    "Q31": {
        "short": "Military_Contact",
        "full": "Does the treaty require official contact among the military forces of the participating states?",
        "question_text": "31. Does the treaty require official contact among the military forces of the participating states? (Yes, No) If Yes, describe. (Note\nwhether official contact is required only in the event of hostilities or also during peacetime.)"
    },
    "Q32": {
        "short": "Military_Aid",
        "full": "Does the treaty include provisions for military aid?",
        "question_text": "32. Does the treaty include provisions for military aid? (e.g., grants, loans, transfer of technology, training) (Yes, No) If Yes, describe\nthese provisions."
    },
    "Q33": {
        "short": "Integrated_Command",
        "full": "Does the treaty provide for integrated command of military forces while the alliance is in effect?",
        "question_text": "33. Does the treaty provide for integrated command of military forces while the alliance is in effect (peacetime as well as wartime)?\n(Yes, No) If Yes, describe."
    },
    "Q34": {
        "short": "Force_Subordination",
        "full": "Does the treaty require subordination of the forces of one or more member states to another in the event of hostilities?",
        "question_text": "34. Does the treaty require subordination of the forces of one or more member states to another in the event of hostilities? (Yes, No) If\nYes, describe."
    },
    "Q35": {
        "short": "Organizations_Established",
        "full": "Does the treaty establish any organizations?",
        "question_text": "35. Does the treaty establish any organizations? (include provisions for regularly scheduled meetings) (Yes, No) If Yes, describe."
    },
    "Q36": {
        "short": "Joint_Bases_Troops",
        "full": "Does the treaty provide for joint military bases, or for one or more states to place troops in the territory of one or more other states?",
        "question_text": "36. Does the treaty provide for joint military bases, or for one or more states to place troops in the territory of one or more other states?\n(Yes, No) If Yes, describe."
    },
    "Q37": {
        "short": "Contribution_Levels",
        "full": "Does the treaty specify contribution levels (funds, troops, etc.)?",
        "question_text": "37. Does the treaty specify contribution levels (funds, troops, etc.)? (Yes, No) If Yes, describe."
    },
    "Q38": {
        "short": "Armament_Provisions",
        "full": "Does the treaty contain any provisions regarding coordinated increase of armaments, reduction of armaments, prohibition of weapons, or rules of warfare?",
        "question_text": "38. Does the treaty contain any provisions regarding coordinated increase of armaments, reduction of armaments, prohibition of\nweapons, or rules of warfare? (Yes, No) If Yes, describe such provisions."
    },
    "Q39": {
        "short": "Territory_Acquisition",
        "full": "Does the treaty explicitly permit or prohibit the acquisition of territory not currently held by either ally?",
        "question_text": "39. Does the treaty explicitly permit or prohibit the acquisition of territory not currently held by either ally? (Yes, No) If Yes, describe\nreference."
    },
    "Q40": {
        "short": "Division_of_Gains",
        "full": "Does the treaty include discussion of the division of gains from any future conflict?",
        "question_text": "40. Does the treaty include discussion of the division of gains from any future conflict? (Yes, No) If Yes, describe."
    },
    "Q41": {
        "short": "Demobilization_Withdrawal",
        "full": "Does the treaty include discussion of demobilization/withdrawal following conflict?",
        "question_text": "41. Does the treaty include discussion of demobilization/withdrawal following conflict? (Yes, No) If Yes, describe."
    },
    "Q42": {
        "short": "Other_Coordination",
        "full": "Are there any other provisions in the treaty that describe the means through which the states will coordinate their military efforts and policies?",
        "question_text": "42. Are there any other provisions in the treaty that describe the means through which the states will coordinate their military efforts and\npolicies? (Yes, No) If Yes, describe."
    },
    "Q43": {
        "short": "Additional_Institutionalization_Comments",
        "full": "Additional coder comments regarding references to alliance institutionalization",
        "question_text": "43. Additional coder comments regarding references to alliance institutionalization:"
    },
    "Q44": {
        "short": "Nullifies_Treaties",
        "full": "Does the treaty state that it nullifies any existing treaties signed by one or more of the contracting parties?",
        "question_text": "44. Does the treaty state that it nullifies any existing treaties signed by one or more of the contracting parties? (Yes, No) If Yes, list the\ntreaties/agreements that are nullified and describe the treaty reference."
    },
    "Q45": {
        "short": "Modifies_Treaties",
        "full": "Does the treaty state that it modifies any existing treaties signed by one or more of the contracting parties?",
        "question_text": "45. Does the treaty state that it modifies any existing treaties signed by one or more of the contracting parties? (Yes, No) If Yes, list the\ntreaties/agreements that are modified and describe the treaty reference."
    },
    "Q46": {
        "short": "Includes_Treaties",
        "full": "Does the treaty state that it includes any existing treaties signed by one or more of the contracting parties?",
        "question_text": "46. Does the treaty state that it includes any existing treaties signed by one or more of the contracting parties? (Yes, No) If Yes, list the\ntreaties/agreements that are included and describe the treaty reference."
    },
    "Q47": {
        "short": "International_Organizations",
        "full": "Does the treaty make any references to international organizations?",
        "question_text": "47. Does the treaty make any references to international organizations? (Yes, No) If Yes, list the international organization and describe\nthe nature of the reference."
    },
    "Q48": {
        "short": "Other_Alliances",
        "full": "Does the treaty make any references to other existing alliances?",
        "question_text": "48. Does the treaty make any references to other existing alliances? (Yes, No) If Yes, list the alliance and describe the nature of the\nreference."
    },
    "Q49": {
        "short": "Companion_Agreements",
        "full": "Are there any companion agreements referenced in the treaty?",
        "question_text": "49. Are there any companion agreements referenced in the treaty? (Yes, No) If Yes, describe the agreements."
    },
    "Q50": {
        "short": "Non_Military_Cooperation",
        "full": "Does the treaty include statements regarding non-military cooperation?",
        "question_text": "50. Does the treaty include statements regarding non-military cooperation (e.g., economic, cultural, scientific exchange)? (Yes, No) If\nYes, describe."
    },
    "Q51": {
        "short": "Resolves_Conflicts",
        "full": "Does the treaty resolve other conflicts among the parties to the alliance?",
        "question_text": "51. Does the treaty resolve other conflicts among the parties to the alliance? (Yes, No) If Yes, describe."
    },
    "Q52": {
        "short": "Enforces_External_Settlement",
        "full": "Does the treaty propose/enforce settlement of a conflict not involving parties to the alliance?",
        "question_text": "52. Does the treaty propose/enforce settlement of a conflict not involving parties to the alliance? (Yes, No) If Yes, describe."
    },
    "Q53": {
        "short": "Proposes_Agreements",
        "full": "Does the treaty propose other agreements among the contracting parties?",
        "question_text": "53. Does the treaty propose other agreements among the contracting parties? (Yes, No) If Yes, describe."
    },
    "Q54": {
        "short": "Unresolved_Conflicts",
        "full": "Does the treaty mention unresolved conflicts among the contracting parties?",
        "question_text": "54. Does the treaty mention unresolved conflicts among the contracting parties? (Yes, No) If Yes, describe."
    },
    "Q55": {
        "short": "Economic_Aid",
        "full": "Does the treaty include provisions for economic aid or other enticements?",
        "question_text": "55. Does the treaty include provisions for economic aid or other enticements (include trade concessions, post war recovery, etc.)? (Yes,\nNo) If Yes, describe these provisions."
    },
    "Q56": {
        "short": "Internal_Politics_Intervention",
        "full": "Does the treaty describe circumstances under which one party may intervene in the internal politics of another party?",
        "question_text": "56. Does the treaty describe circumstances under which one party may intervene in the internal politics of another party or specifically\ncommit the states to non-intervention? (Yes, No) If Yes, describe."
    },
    "Q57": {
        "short": "Additional_Comments",
        "full": "Additional coder comments on this alliance treaty",
        "question_text": "57. Additional coder comments on this alliance treaty:"
    },
    "Q58": {
        "short": "Source_of_Coding",
        "full": "Source of coding information",
        "question_text": "58. Source of coding information (e.g., treaty, treaty and secondary sources, secondary sources only, etc.):"
    },
    "Q59": {
        "short": "Treaty_Citation",
        "full": "Treaty citation",
        "question_text": "59. Treaty citation:"
    },
    "Q60": {
        "short": "Last_Revision_Date",
        "full": "Date of last revision of this coding sheet",
        "question_text": "60. Date of last revision of this coding sheet:"
    },
    "Q61": {
        "short": "Coder",
        "full": "Coder",
        "question_text": "61. Coder:"
    }
}

def parse_single_date(text):
    """
    Return ISO date ('YYYY-MM-DD') if `text` looks like a date.
    Otherwise return None.
    """
    try:
        clean = text.strip().rstrip('.')        # drop trailing period
        dt = _dt_parse(clean, fuzzy=True)       # handles 'March 9, 1833'
        return dt.date().isoformat()
    except (ValueError, OverflowError):
        return None

def extract_countries(text):
    """
    Return a semicolon-separated string of CountryName(code) pairs found in `text`.
    Handles both '365 Russia 200 United Kingdom.' and 'Russia (365)' layouts, collecting ALL occurrences.
    """
    pairs = []

    # Pattern A – code first, then name (e.g. "365 Russia 200 United Kingdom.")
    for code, name in re.findall(
        r'\b(\d{3})\s+([A-Z][A-Za-z.\- ]+?)'               # capture 3-digit code + country name
        r'(?='                                             # but stop when you see:
          r'(?:\s+\d{3}\s)'      #   – another code (e.g. " 200 ")
          r'|[.,;\n]'            #   – or punctuation: . , ; or newline
          r'|$'                  #   – or end-of-string
        r')',
        text
    ):
        pair = f"{name.strip()}({code})"
        if pair not in pairs:
            pairs.append(pair)

    # Pattern B – name first, then code in parentheses (e.g. "Russia (365)")
    for name, code in re.findall(
        r'\b([A-Z][A-Za-z.\- ]+?)\s*\(\s*(\d{3})\s*\)',
        text
    ):
        pair = f"{name.strip()}({code})"
        if pair not in pairs:
            pairs.append(pair)

    return ";".join(pairs)





def extract_text_from_pdf(pdf_path):
    """Extract text from PDF file using pdfplumber"""
    print(f"Extracting text from {pdf_path}")
    
    try:
        with pdfplumber.open(pdf_path) as pdf:
            # Extract text from all pages
            raw_text = "\n".join(
                page.extract_text() or ""  # returns '' if page is image-only
                for page in pdf.pages
            )
        
        # Clean up multiple newlines
        raw_text_clean = re.sub(r"\n{2,}", "\n\n", raw_text)
        
        print(f"✓ Extracted {len(raw_text):,} characters from {Path(pdf_path).name}")
        return raw_text_clean
    
    except Exception as e:
        print(f"Error extracting text from {pdf_path}: {str(e)}")
        return None

def categorize_answer(answer_text):
    """Categorize the answer based on its content"""
    answer_clean = answer_text.strip()
    
    # Check for Yes/No answers
    if answer_clean.lower() in ['yes', 'no', 'yes.', 'no.', 'n/a', 'n/a.', 'zero', 'zero.']:
        return "Yes/No+Text"
    
    # Check for coded list answers (contains semicolons or specific patterns)
    if ';' in answer_clean and len(answer_clean) < 100:
        return "Coded_List"
    
    # Check for multiple items (contains "and" or comma-separated short items)
    if (',' in answer_clean or ' and ' in answer_clean.lower()) and len(answer_clean) < 100:
        return "Multiple"
    
    
    # Check for numeric answers
    if re.match(r'^\d+\.?$', answer_clean):
        return "Numeric"
    
    # Default to text for longer answers
    return "Text"

import re

def fast_extract_answers(text, alliance_id=None, alliance_name=None):
    """
    Fast extraction using whitespace-flattened search so that slight
    differences in line breaks or punctuation don’t break question matching.
    Returns a list of row dicts with keys:
      Alliance_ID, Alliance_Name, Question_ID, Question_Short, Question_Full,
      Answer_YesNo, Answer_Text, Answer_Category, Decoded_Countries, Text_Length
    """
    # —————————————— Alliance ID / Name logic (unchanged) ——————————————
    if alliance_id is None:
        id_pos = text.find("1. ATOP ID:")
        if id_pos != -1:
            start = id_pos + len("1. ATOP ID:")
            end   = text.find("\n", start)
            alliance_id = text[start:end].strip().replace("#", "").strip()
        else:
            alliance_id = "Unknown"
    if alliance_name is None:
        alliance_name = f"Alliance_{alliance_id}"

    # —————————————— Flatten for robust searching ——————————————
    text_search = re.sub(r"\s+", " ", text).strip()

    # —————————————— Locate every question position ——————————————
    question_positions = []
    for q_id, q_info in QUESTIONS.items():
        q_flat = re.sub(r"\s+", " ", q_info["question_text"]).strip()
        matches = [m.start() for m in re.finditer(re.escape(q_flat), text_search)]
        if matches:
            pos = matches[-1]
            question_positions.append((q_id, pos, len(q_flat), q_info))
    question_positions.sort(key=lambda x: x[1])

    rows = []
    # —————————————— Extract each answer block ——————————————
    for i, (q_id, pos, plen, q_info) in enumerate(question_positions):
        answer_start = pos + plen
        if i + 1 < len(question_positions):
            answer_end = question_positions[i + 1][1]
        else:
            # last question → up to common markers or end
            answer_end = len(text_search)
            for marker in ["SECTION", "Source:", "Date of last revision:"]:
                mpos = text_search.find(marker, answer_start)
                if 0 <= mpos < answer_end:
                    answer_end = mpos

        # slice & basic cleanup
        answer_text = text_search[answer_start:answer_end].strip()
        answer_text = re.sub(r'^#\s*', '', answer_text)  # drop leading "# "
        
        

        answer_text = re.sub(
            r'^See\s+#?\s*\d+\s+below[^\n]*\n?',
            '',
            answer_text,
            flags=re.I
        )
        answer_text = re.sub(
            r'^SECTION\s+[IVXLCDM]+\s*:[^\n]*\n?',
            '',
            answer_text,
            flags=re.I | re.M
        )
        # 3️⃣ NEW — remove SECTION headers anywhere (e.g. inline bleed)
        answer_text = re.sub(
            r'\bSECTION\s+[IVXLCDM]+\s*:\s*[A-Za-z ]+\b',
            '',
            answer_text,
            flags=re.I
        )
        answer_text = re.sub(r'\s+', ' ', answer_text)

        # Yes/No flag
        answer_yesno = "N/A"
        low = answer_text.lower()
        if low.startswith("yes"):
            answer_yesno = "Yes"
        elif low.startswith("no"):
            answer_yesno = "No"

        # decode any countries
        decoded = extract_countries(answer_text)

        # categorization (with Q3/Q14 → Date override)
        if q_id in ("Q3", "Q14"):
            iso = parse_single_date(answer_text)
            if iso:
                answer_text = iso
            answer_category = "Date"
        else:
            if decoded:
                answer_category = "coded_text"
            else:
                answer_category = categorize_answer(answer_text)

        # final row assembly
        row = {
            "Alliance_ID":      alliance_id,
            "Alliance_Name":    alliance_name,
            "Question_ID":      q_id,
            "Question_Short":   q_info["short"],
            "Question_Full":    q_info["full"],
            "Answer_YesNo":     answer_yesno,
            "Answer_Text":      answer_text,
            "Answer_Category":  answer_category,
            "Decoded_Countries": decoded,
            "Text_Length":      len(answer_text)
        }
        rows.append(row)
        for row in rows:
        # Fix Q18 bleeding into Q19
            if row["Question_ID"] == "Q18" and "19. Are any of the obligations contingent" in row["Answer_Text"]:
                full_text = row["Answer_Text"]
                split_pos = full_text.find("19. Are any of the obligations contingent")
                
                # Clean Q18 answer
                row["Answer_Text"] = full_text[:split_pos].strip()
                row["Text_Length"] = len(row["Answer_Text"])
                
                # Extract Q19 answer (everything after the Q19 question text)
                q19_part = full_text[split_pos:]
                # Find where the actual answer starts (after the question text)
                q19_answer_start = q19_part.find("(List all that apply)")
                if q19_answer_start != -1:
                    q19_answer = q19_part[q19_answer_start + len("(List all that apply)"):].strip()
                else:
                    # Fallback: take everything after a reasonable chunk of the question
                    q19_answer = q19_part[200:].strip()  # Skip ~200 chars of question text
                
                # Find Q19 row and populate it
                for q19_row in rows:
                    if q19_row["Question_ID"] == "Q19":
                        q19_row["Answer_Text"] = q19_answer
                        q19_row["Answer_YesNo"] = "Yes" if q19_answer.lower().startswith("yes") else ("No" if q19_answer.lower().startswith("no") else "N/A")
                        q19_row["Answer_Category"] = categorize_answer(q19_answer)
                        q19_row["Text_Length"] = len(q19_answer)
                        q19_row["Decoded_Countries"] = extract_countries(q19_answer)
                        break
            
            # Fix Q49 bleeding into Q50
            elif row["Question_ID"] == "Q49" and "50. Does the treaty include statements" in row["Answer_Text"]:
                full_text = row["Answer_Text"]
                split_pos = full_text.find("50. Does the treaty include statements")
                
                # Clean Q49 answer
                row["Answer_Text"] = full_text[:split_pos].strip()
                row["Text_Length"] = len(row["Answer_Text"])
                
                # Extract Q50 answer
                q50_part = full_text[split_pos:]
                # Find where the actual answer starts (after the question text)
                q50_answer_start = q50_part.find("(Yes, No)")
                if q50_answer_start != -1:
                    q50_answer = q50_part[q50_answer_start + len("(Yes, No)"):].strip()
                else:
                    # Fallback: take everything after a reasonable chunk of the question
                    q50_answer = q50_part[150:].strip()  # Skip ~150 chars of question text
                
                # Find Q50 row and populate it
                for q50_row in rows:
                    if q50_row["Question_ID"] == "Q50":
                        q50_row["Answer_Text"] = q50_answer
                        q50_row["Answer_YesNo"] = "Yes" if q50_answer.lower().startswith("yes") else ("No" if q50_answer.lower().startswith("no") else "N/A")
                        q50_row["Answer_Category"] = categorize_answer(q50_answer)
                        q50_row["Text_Length"] = len(q50_answer)
                        q50_row["Decoded_Countries"] = extract_countries(q50_answer)
                        break



    # —————————————— Fill in any missing questions ——————————————
    found = {r["Question_ID"] for r in rows}
    for q_id, q_info in QUESTIONS.items():
        if q_id not in found:
            rows.append({
                "Alliance_ID":      alliance_id,
                "Alliance_Name":    alliance_name,
                "Question_ID":      q_id,
                "Question_Short":   q_info["short"],
                "Question_Full":    q_info["full"],
                "Answer_YesNo":     "Not Found",
                "Answer_Text":      "",
                "Answer_Category":  "Missing",
                "Decoded_Countries": "",
                "Text_Length":      0
            })

    # —————————————— Sort by question number & return ——————————————
    rows.sort(key=lambda r: int(r["Question_ID"][1:]))
    return rows


def process_single_pdf(pdf_path, alliance_id=None, alliance_name=None, save_text=False):
    """Process a single ATOP PDF file and extract data"""
    
    # Extract text from PDF
    text = extract_text_from_pdf(pdf_path)
    
    if text is None:
        print(f"Failed to extract text from {pdf_path}")
        return None
    
    # Optionally save extracted text
    if save_text:
        txt_path = Path(pdf_path).with_suffix('.txt')
        txt_path.write_text(text, encoding='utf-8')
        print(f"Text saved to: {txt_path}")
    
    # Extract alliance ID from filename if not provided
    if alliance_id is None:
        file_name = Path(pdf_path).stem
        alliance_id_match = re.search(r'ATOP(\d+)', file_name)
        alliance_id = alliance_id_match.group(1) if alliance_id_match else "Unknown"
    
    # Extract answers using fast method
    rows = fast_extract_answers(text, alliance_id, alliance_name)
    
    # Convert to DataFrame
    df = pd.DataFrame(rows)
    
    return df

def process_multiple_pdfs(pdf_paths, output_csv="atop_extracted_data.csv", save_text_files=False):
    """Process multiple ATOP PDF files and combine results"""
    
    all_dfs = []
    failed_files = []
    
    for i, pdf_path in enumerate(pdf_paths):
        print(f"\nProcessing file {i+1}/{len(pdf_paths)}: {Path(pdf_path).name}")
        
        try:
            df = process_single_pdf(pdf_path, save_text=save_text_files)
            
            if df is not None:
                all_dfs.append(df)
            else:
                failed_files.append(pdf_path)
                
        except Exception as e:
            print(f"Error processing {pdf_path}: {str(e)}")
            failed_files.append(pdf_path)
    
    # Combine all dataframes
    if all_dfs:
        combined_df = pd.concat(all_dfs, ignore_index=True)
        
        # Save to CSV
        combined_df.to_csv(output_csv, index=False)
        print(f"\n✓ Data from {len(all_dfs)} files saved to {output_csv}")
        
        if failed_files:
            print(f"\n⚠ Failed to process {len(failed_files)} files:")
            for f in failed_files:
                print(f"  - {Path(f).name}")
        
        return combined_df
    else:
        print("No data extracted from any files.")
        return None

# Example usage functions
def demo_single_pdf():
    """Demo: Process a single PDF file"""
    pdf_path = GLOBAL_SINGLE_PDF
    
    # Process the PDF
    df = process_single_pdf(
        pdf_path,
        alliance_id="1005",
        alliance_name="Quadruple Alliance",
        save_text=True  # This will also save the extracted text
    )
    
    if df is not None:
        # Display sample results
        print("\nSample extracted data:")
        print(df[['Question_ID', 'Question_Short', 'Answer_Text']].head(10))
        
        # Save to CSV
        df.to_csv("atop_1005_extracted.csv", index=False)
        print(f"\nData saved to atop_1005_extracted.csv")
        #df.head()
        return df

import glob
from pathlib import Path


def demo_v5_processing():
    """Process only ATOP PDFs whose filenames end with 'v4' (case-insensitive)."""
    # 1️⃣ Glob for everything under ATOP*.pdf
    pdf_pattern = "atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets/ATOP*.pdf"
    all_pdfs = glob.glob(pdf_pattern)

    # 2️⃣ Keep only those whose stem ends with 'v4'
    v4_pdfs = [
        f for f in all_pdfs
        if Path(f).stem.lower().endswith("v5")
    ]

    print(f"Found {len(v4_pdfs)} ATOP v5 PDF files to process")

    # 3️⃣ Process just the v4 files
    combined_df = process_multiple_pdfs(
        v4_pdfs,
        output_csv="all_atop_v5_data.csv",
        save_text_files=False
    )

    if combined_df is not None:
        print(f"\nTotal records extracted from v5 files: {len(combined_df)}")
        print(f"Unique alliances in v5 set: {combined_df['Alliance_ID'].nunique()}")



# Main execution
if __name__ == "__main__":
    # Choose one of the demo functions to run
    # df = demo_single_pdf()
    demo_v5_processing()
    print("\nProcessing complete for version 5 variant. DataFrame ready for analysis.")
# Out:
# Installing python-dateutil...
# Found 49 ATOP v5 PDF files to process
#
# Processing file 1/49: ATOP1323v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1323v5.pdf
# ✓ Extracted 10,799 characters from ATOP1323v5.pdf
#
# Processing file 2/49: ATOP1358v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1358v5.pdf
# ✓ Extracted 13,593 characters from ATOP1358v5.pdf
#
# Processing file 3/49: ATOP1362v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP1362v5.pdf
# ✓ Extracted 17,183 characters from ATOP1362v5.pdf
#
# Processing file 4/49: ATOP3222v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3222v5.pdf
# ✓ Extracted 12,481 characters from ATOP3222v5.pdf
#
# Processing file 5/49: ATOP3333v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3333v5.pdf
# ✓ Extracted 11,763 characters from ATOP3333v5.pdf
#
# Processing file 6/49: ATOP3367v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3367v5.pdf
# ✓ Extracted 10,802 characters from ATOP3367v5.pdf
#
# Processing file 7/49: ATOP3373v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3373v5.pdf
# ✓ Extracted 10,956 characters from ATOP3373v5.pdf
#
# Processing file 8/49: ATOP3424v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3424v5.pdf
# ✓ Extracted 10,528 characters from ATOP3424v5.pdf
#
# Processing file 9/49: ATOP3433v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3433v5.pdf
# ✓ Extracted 11,246 characters from ATOP3433v5.pdf
#
# Processing file 10/49: ATOP3452v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3452v5.pdf
# ✓ Extracted 11,252 characters from ATOP3452v5.pdf
#
# Processing file 11/49: ATOP3458v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3458v5.pdf
# ✓ Extracted 10,564 characters from ATOP3458v5.pdf
#
# Processing file 12/49: ATOP3537v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3537v5.pdf
# ✓ Extracted 10,362 characters from ATOP3537v5.pdf
#
# Processing file 13/49: ATOP3678v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3678v5.pdf
# ✓ Extracted 11,379 characters from ATOP3678v5.pdf
#
# Processing file 14/49: ATOP3679v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3679v5.pdf
# ✓ Extracted 11,287 characters from ATOP3679v5.pdf
#
# Processing file 15/49: ATOP3918v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP3918v5.pdf
# ✓ Extracted 12,833 characters from ATOP3918v5.pdf
#
# Processing file 16/49: ATOP4341v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4341v5.pdf
# ✓ Extracted 16,789 characters from ATOP4341v5.pdf
#
# Processing file 17/49: ATOP4392v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4392v5.pdf
# ✓ Extracted 14,289 characters from ATOP4392v5.pdf
#
# Processing file 18/49: ATOP4441v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4441v5.pdf
# ✓ Extracted 14,284 characters from ATOP4441v5.pdf
#
# Processing file 19/49: ATOP4520v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4520v5.pdf
# ✓ Extracted 11,102 characters from ATOP4520v5.pdf
#
# Processing file 20/49: ATOP4678v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4678v5.pdf
# ✓ Extracted 21,817 characters from ATOP4678v5.pdf
#
# Processing file 21/49: ATOP4735v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4735v5.pdf
# ✓ Extracted 12,141 characters from ATOP4735v5.pdf
#
# Processing file 22/49: ATOP4758v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4758v5.pdf
# ✓ Extracted 12,026 characters from ATOP4758v5.pdf
#
# Processing file 23/49: ATOP4792v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4792v5.pdf
# ✓ Extracted 14,302 characters from ATOP4792v5.pdf
#
# Processing file 24/49: ATOP4833v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4833v5.pdf
# ✓ Extracted 16,286 characters from ATOP4833v5.pdf
#
# Processing file 25/49: ATOP4864v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4864v5.pdf
# ✓ Extracted 14,477 characters from ATOP4864v5.pdf
#
# Processing file 26/49: ATOP4869v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4869v5.pdf
# ✓ Extracted 11,518 characters from ATOP4869v5.pdf
#
# Processing file 27/49: ATOP4897v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4897v5.pdf
# ✓ Extracted 10,824 characters from ATOP4897v5.pdf
#
# Processing file 28/49: ATOP4965v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP4965v5.pdf
# ✓ Extracted 13,376 characters from ATOP4965v5.pdf
#
# Processing file 29/49: ATOP5000v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP5000v5.pdf
# ✓ Extracted 12,201 characters from ATOP5000v5.pdf
#
# Processing file 30/49: ATOP5022v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP5022v5.pdf
# ✓ Extracted 12,706 characters from ATOP5022v5.pdf
#
# Processing file 31/49: ATOP5034v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP5034v5.pdf
# ✓ Extracted 15,037 characters from ATOP5034v5.pdf
#
# Processing file 32/49: ATOP5053v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP5053v5.pdf
# ✓ Extracted 11,766 characters from ATOP5053v5.pdf
#
# Processing file 33/49: ATOP5064v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP5064v5.pdf
# ✓ Extracted 12,190 characters from ATOP5064v5.pdf
#
# Processing file 34/49: ATOP5072v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP5072v5.pdf
# ✓ Extracted 13,475 characters from ATOP5072v5.pdf
#
# Processing file 35/49: ATOP6032v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6032v5.pdf
# ✓ Extracted 15,924 characters from ATOP6032v5.pdf
#
# Processing file 36/49: ATOP6053v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6053v5.pdf
# ✓ Extracted 11,973 characters from ATOP6053v5.pdf
#
# Processing file 37/49: ATOP6070v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6070v5.pdf
# ✓ Extracted 13,376 characters from ATOP6070v5.pdf
#
# Processing file 38/49: ATOP6075v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6075v5.pdf
# ✓ Extracted 10,955 characters from ATOP6075v5.pdf
#
# Processing file 39/49: ATOP6080v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6080v5.pdf
# ✓ Extracted 13,548 characters from ATOP6080v5.pdf
#
# Processing file 40/49: ATOP6085v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6085v5.pdf
# ✓ Extracted 11,249 characters from ATOP6085v5.pdf
#
# Processing file 41/49: ATOP6095v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP6095v5.pdf
# ✓ Extracted 11,648 characters from ATOP6095v5.pdf
#
# Processing file 42/49: ATOP7005v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP7005v5.pdf
# ✓ Extracted 11,705 characters from ATOP7005v5.pdf
#
# Processing file 43/49: ATOP7015v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP7015v5.pdf
# ✓ Extracted 11,492 characters from ATOP7015v5.pdf
#
# Processing file 44/49: ATOP7025v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP7025v5.pdf
# ✓ Extracted 12,385 characters from ATOP7025v5.pdf
#
# Processing file 45/49: ATOP7030v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP7030v5.pdf
# ✓ Extracted 11,939 characters from ATOP7030v5.pdf
#
# Processing file 46/49: ATOP7040v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP7040v5.pdf
# ✓ Extracted 17,412 characters from ATOP7040v5.pdf
#
# Processing file 47/49: ATOP7043v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP7043v5.pdf
# ✓ Extracted 12,682 characters from ATOP7043v5.pdf
#
# Processing file 48/49: ATOP7045v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP7045v5.pdf
# ✓ Extracted 11,055 characters from ATOP7045v5.pdf
#
# Processing file 49/49: ATOP7050v5.pdf
# Extracting text from atop_version_5.1_codesheets/ATOP Version 5.1 Codesheets\ATOP7050v5.pdf
# ✓ Extracted 11,209 characters from ATOP7050v5.pdf
#
# ✓ Data from 49 files saved to all_atop_v5_data.csv
#
# Total records extracted from v5 files: 2989
# Unique alliances in v5 set: 49
#
# Processing complete for version 5 variant. DataFrame ready for analysis.

# %%
import pandas as pd

# 1. Define relative paths to your input CSVs
paths = {
    'base': 'all_atop_data.csv',
    'v4':   'all_atop_v4_data.csv',
    'v5':   'all_atop_v5_data.csv'
}

# 2. Load each, tag with version
dfs = []
for version, path in paths.items():
    df = pd.read_csv(path)
    df['version'] = version
    dfs.append(df)

# 3. Concatenate into one DataFrame
merged = pd.concat(dfs, ignore_index=True)

# 4. Write out to CSV
out_csv  = 'ATOP_treaty_text_20250703.csv'
merged.to_csv(out_csv, index=False)

# 5. Write out to JSON (list of records)
out_json = 'ATOP_treaty_text_20250703.json'
merged.to_json(out_json, orient='records', force_ascii=False, indent=2)

print(f"Saved merged data to:\n  • {out_csv}\n  • {out_json}")
# Out:
# Saved merged data to:
#   • ATOP_treaty_text_20250703.csv
#   • ATOP_treaty_text_20250703.json
